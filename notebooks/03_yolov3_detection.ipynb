# %% [markdown]
# <font color="#de3023"><h1><b>REMINDER MAKE A COPY OF THIS NOTEBOOK, DO NOT EDIT</b></h1></font>

# %% [markdown]
# Today, we'll learn one of the most widely used state-of-the-art object detection algorithms -- YOLO. We'll apply this algorithm on both images and videos.
#
# Click on the image below to see some amazing results!
#
# [<img src="https://miro.medium.com/v2/resize:fit:1400/1*bSLNlG7crv-p-m4LVYYk3Q.png" width="400"/>](https://www.youtube.com/watch?v=MPU2HistivI)
#
#
# Let's get started!

# %% [markdown]
# In this notebook we'll be:
# 1.   Understanding YOLO
# 2.   Performing Bounding Box Prediction
# 3.   Performing Object Detection on Videos

# %%
#@title Run this to download data and prepare our environment! { display-mode: "form" }

import matplotlib.pyplot as plt
import os
from PIL import Image
import gdown

import argparse
import numpy as np
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D
from keras.layers import concatenate, add
from keras.models import Model
import struct
import cv2
from copy import deepcopy

# Prepare data
DATA_ROOT = '/content/data'
os.makedirs(DATA_ROOT, exist_ok=True)

# image_url = 'https://drive.google.com/uc?id=12ZpZ5H0kJIkWk6y4ktGfqR5OTKofL7qw'
# image_path = os.path.join(DATA_ROOT, 'image.jpg')
# gdown.download(image_url, image_path, True)
# !wget -O /content/data/image.jpg "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/image.jpg"

# image2_url = 'https://drive.google.com/uc?id=1_WpFbGEuS2r19UeP6wekbcF0kb-0nH18'
# image2_path = os.path.join(DATA_ROOT, 'image2.jpg')
# gdown.download(image2_url, image2_path, True)
# !wget -O /content/data/image2.jpg "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/image2.jpg"

# video_url = 'https://drive.google.com/uc?id=1xFGjpzhZVYtNor9hJevvxysGESZJIMDz'
# video_path = os.path.join(DATA_ROOT, 'video1.mp4')
# gdown.download(video_url, video_path, True)
# !wget -O /content/data/video1.mp4 "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/6.mp4"

# model_url = 'https://drive.google.com/uc?id=19XKJWMKDfDlag2MR8ofjwvxhtr9BxqqN'
model_path = os.path.join(DATA_ROOT, 'yolo_weights.h5')
# gdown.download(model_url, model_path, True)
# !wget -O /content/data/yolo_weights.h5 "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/yolo.h5"

labels = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", \
              "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", \
              "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", \
              "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", \
              "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", \
              "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", \
              "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", \
              "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse", \
              "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", \
              "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]

class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax

        self.objness = objness
        self.classes = classes

        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)

        return self.label

    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]

        return self.score

def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b

    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])

    intersect = intersect_w * intersect_h

    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin

    union = w1*h1 + w2*h2 - intersect

    return float(intersect) / union

def preprocess_input(image_pil, net_h, net_w):
    image = np.asarray(image_pil)
    new_h, new_w, _ = image.shape
    # print("net:", net_h, net_w)
    # print("old:",new_h, new_w)
    # determine the new size of the image
    if (float(net_w)/new_w) < (float(net_h)/new_h):
        new_h = (new_h * net_w)/new_w
        new_w = net_w
    else:
        new_w = (new_w * net_h)/new_h
        new_h = net_h
    new_w = int(new_w)
    new_h = int(new_h)
    # print("new:",int(new_h), int(new_w))
    # resize the image to the new size
    #resized = cv2.resize(image[:,:,::-1]/255., (int(new_w), int(new_h)))
    resized = cv2.resize(image/255., (int(new_w), int(new_h)))

    # embed the image into the standard letter box
    # print("dims:",int((net_h-new_h)//2), int((net_h+new_h)//2), int((net_w-new_w)//2), int((net_w+new_w)//2))
    new_image = np.ones((net_h, net_w, 3)) * 0.5
    new_image[int((net_h-new_h)//2):int((net_h+new_h)//2), int((net_w-new_w)//2):int((net_w+new_w)//2), :] = resized
    new_image = np.expand_dims(new_image, 0)
    # print(new_image.shape)


    return new_image


def decode_netout(netout_, obj_thresh, anchors_, image_h, image_w, net_h, net_w):
    netout_all = deepcopy(netout_)
    boxes_all = []
    for i in range(len(netout_all)):
      netout = netout_all[i][0]
      anchors = anchors_[i]

      grid_h, grid_w = netout.shape[:2]
      nb_box = 3
      netout = netout.reshape((grid_h, grid_w, nb_box, -1))
      nb_class = netout.shape[-1] - 5

      boxes = []

      netout[..., :2]  = _sigmoid(netout[..., :2])
      netout[..., 4:]  = _sigmoid(netout[..., 4:])
      netout[..., 5:]  = netout[..., 4][..., np.newaxis] * netout[..., 5:]
      netout[..., 5:] *= netout[..., 5:] > obj_thresh

      for i in range(grid_h*grid_w):
          row = i // grid_w
          col = i % grid_w

          for b in range(nb_box):
              # 4th element is objectness score
              objectness = netout[row][col][b][4]
              #objectness = netout[..., :4]
              # last elements are class probabilities
              classes = netout[row][col][b][5:]

              if((classes <= obj_thresh).all()): continue

              # first 4 elements are x, y, w, and h
              x, y, w, h = netout[row][col][b][:4]

              x = (col + x) / grid_w # center position, unit: image width
              y = (row + y) / grid_h # center position, unit: image height
              w = anchors[b][0] * np.exp(w) / net_w # unit: image width
              h = anchors[b][1] * np.exp(h) / net_h # unit: image height

              box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, objectness, classes)
              #box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, None, classes)

              boxes.append(box)

      boxes_all += boxes

    # Correct boxes
    boxes_all = correct_yolo_boxes(boxes_all, image_h, image_w, net_h, net_w)

    return boxes_all

def correct_yolo_boxes(boxes_, image_h, image_w, net_h, net_w):
    boxes = deepcopy(boxes_)
    if (float(net_w)/image_w) < (float(net_h)/image_h):
        new_w = net_w
        new_h = (image_h*net_w)/image_w
    else:
        new_h = net_w
        new_w = (image_w*net_h)/image_h

    for i in range(len(boxes)):
        x_offset, x_scale = (net_w - new_w)/2./net_w, float(new_w)/net_w
        y_offset, y_scale = (net_h - new_h)/2./net_h, float(new_h)/net_h

        boxes[i].xmin = int((boxes[i].xmin - x_offset) / x_scale * image_w)
        boxes[i].xmax = int((boxes[i].xmax - x_offset) / x_scale * image_w)
        boxes[i].ymin = int((boxes[i].ymin - y_offset) / y_scale * image_h)
        boxes[i].ymax = int((boxes[i].ymax - y_offset) / y_scale * image_h)
    return boxes

def do_nms(boxes_, nms_thresh, obj_thresh):
    boxes = deepcopy(boxes_)
    if len(boxes) > 0:
        num_class = len(boxes[0].classes)
    else:
        return

    for c in range(num_class):
        sorted_indices = np.argsort([-box.classes[c] for box in boxes])

        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]

            if boxes[index_i].classes[c] == 0: continue

            for j in range(i+1, len(sorted_indices)):
                index_j = sorted_indices[j]

                if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_thresh:
                    boxes[index_j].classes[c] = 0

    new_boxes = []
    for box in boxes:
        label = -1

        for i in range(num_class):
            if box.classes[i] > obj_thresh:
                label = i
                # print("{}: {}, ({}, {})".format(labels[i], box.classes[i]*100, box.xmin, box.ymin))
                box.label = label
                box.score = box.classes[i]
                new_boxes.append(box)

    return new_boxes


from PIL import ImageDraw, ImageFont
import colorsys

def draw_boxes(image_, boxes, labels):
    image = image_.copy()
    image_w, image_h = image.size
    font = ImageFont.truetype(font='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf',
                    size=np.floor(3e-2 * image_h + 0.5).astype('int32'))
    thickness = (image_w + image_h) // 300

    # Generate colors for drawing bounding boxes.
    hsv_tuples = [(x / len(labels), 1., 1.)
                  for x in range(len(labels))]
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(
        map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))
    np.random.seed(10101)  # Fixed seed for consistent colors across runs.
    np.random.shuffle(colors)  # Shuffle colors to decorrelate adjacent classes.
    np.random.seed(None)  # Reset seed to default.

    for i, box in reversed(list(enumerate(boxes))):
        c = box.get_label()
        predicted_class = labels[c]
        score = box.get_score()
        top, left, bottom, right = box.ymin, box.xmin, box.ymax, box.xmax

        label = '{} {:.2f}'.format(predicted_class, score)
        draw = ImageDraw.Draw(image)
        label_size = draw.textbbox((0,0),label, font)
        label_size = (label_size[2], label_size[3])

        top = max(0, np.floor(top + 0.5).astype('int32'))
        left = max(0, np.floor(left + 0.5).astype('int32'))
        bottom = min(image_h, np.floor(bottom + 0.5).astype('int32'))
        right = min(image_w, np.floor(right + 0.5).astype('int32'))
        print(label, (left, top), (right, bottom))

        if top - label_size[1] >= 0:
            text_origin = np.array([left, top - label_size[1]])
        else:
            text_origin = np.array([left, top + 1])

        if right > left and bottom > top:
          # proceed to draw the box
          draw.rectangle([left, top, right, bottom], outline=colors[c], width=thickness)
        else:
          print(f"Invalid box: {(left, top, right, bottom)}")

        draw.text(text_origin, label, fill=(0, 0, 0), font=font)
        #draw.text(text_origin, label, fill=(0, 0, 0))
        del draw
    return image
# Out:
# --2025-08-06 20:35:58--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/image.jpg
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 142.250.99.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94721 (93K) [image/jpeg]
# Saving to: ‘/content/data/image.jpg’
#
# /content/data/image 100%[===================>]  92.50K  --.-KB/s    in 0.001s
#
# 2025-08-06 20:35:58 (101 MB/s) - ‘/content/data/image.jpg’ saved [94721/94721]
#
# --2025-08-06 20:35:58--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/image2.jpg
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 142.250.99.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79135 (77K) [image/jpeg]
# Saving to: ‘/content/data/image2.jpg’
#
# /content/data/image 100%[===================>]  77.28K  --.-KB/s    in 0.001s
#
# 2025-08-06 20:35:58 (110 MB/s) - ‘/content/data/image2.jpg’ saved [79135/79135]
#
# --2025-08-06 20:35:58--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/6.mp4
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 142.250.99.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3734507 (3.6M) [video/mp4]
# Saving to: ‘/content/data/video1.mp4’
#
# /content/data/video 100%[===================>]   3.56M  --.-KB/s    in 0.07s
#
# 2025-08-06 20:35:59 (48.2 MB/s) - ‘/content/data/video1.mp4’ saved [3734507/3734507]
#
# --2025-08-06 20:35:59--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20%20Object%20Detection%20(Autonomous%20Vehicles)/yolo.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 142.250.99.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248686624 (237M) [application/octet-stream]
# Saving to: ‘/content/data/yolo_weights.h5’
#
# /content/data/yolo_ 100%[===================>] 237.17M   125MB/s    in 1.9s
#
# 2025-08-06 20:36:01 (125 MB/s) - ‘/content/data/yolo_weights.h5’ saved [248686624/248686624]

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Milestone 1. What is YOLO?

# %% [markdown]
# The “You Only Look Once,” or YOLO, family of models are a series of end-to-end deep learning models designed for fast object detection, developed by Joseph Redmon, et al. and first proposed in the 2015 paper titled “[You Only Look Once: Unified, Real-Time Object Detection](https://arxiv.org/abs/1506.02640).” The model has been updated since then. Today, we'll focus on YOLOv3, which is described in this very interesting [technical report](https://pjreddie.com/media/files/papers/YOLOv3.pdf). Today, we'll walk through the basic idea of the algorithm. If you'd like to know more details about it, definitely check out the papers!
#
# The approach involves a single deep convolutional neural network (DarkNet, based on the VGG models) that splits the input into a grid of cells, with each cell directly predicting a bounding box and object classification. The result is a large number of candidate bounding boxes that are consolidated into a final prediction by a post-processing step.
#
# For example, an image may be divided into a 7×7 grid and each cell in the grid may predict 2 bounding boxes, resulting in 98 proposed bounding box predictions. The class probabilities map and the bounding boxes with confidences are then combined into a final set of bounding boxes and class labels. The image taken from the paper below summarizes the two outputs of the model.
#
# In summary, to make object detection on one input image, the first step is a forward pass of the DarkNet; the second step is the post-processing on the DarkNet output to get the final bounding boxes prediction.
#
# ![](https://drive.google.com/uc?export=view&id=1-IuBrnrTZPOb4zZXGLl6Kn4OKsX9NnXR)

# %% [markdown]
# # Milestone 2. How does YOLO work?

# %% [markdown]
# Before we proceed to build the YOLO model, let's first define the **anchor boxes**, which are several pre-defined bounding boxes with useful shapes and sizes that are tailored based on the object shapes in the training dataset.
#
# There are 9 anchor boxes in total. As we'll talk about later, the detection is performed on 3 scales. Therefore, the anchor boxes are divided into 3 groups, each corresponding to 1 scale.

# %%
anchors = [[[116,90], [156,198], [373,326]], [[30,61], [62,45], [59,119]], [[10,13], [16,30], [33,23]]]

# %% [markdown]
# The 9 anchor boxes are plotted below. As you may discover, they can cover a variety of shapes and sizes.
#
# <img src="https://datadrivenscience.com/wp-content/uploads/elementor/thumbs/anchor-boxes-qd8qcceloi4053qf9nwbk1cwnx3pmnwfqdp1b03pj4.png" width="400"/>

# %% [markdown]
# Now, let's load the image that we'll apply object detection on. To load the image, we'll use the `Image` module in the package `PIL`, which is commonly used  for image processing. The image is saved as a `PIL image` in the variable `image_pil`. We can get the width and the height of the image by accessing the `size` attribute of the image.

# %%
from PIL import Image
from matplotlib import  pyplot as plt

image_path = '/content/data/image.jpg'

image_pil = Image.open(image_path)
image_w, image_h = image_pil.size
print("The type of the saved image is {}".format(type(image_pil)))
plt.imshow(image_pil)
plt.show()
# Out:
# The type of the saved image is <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ### Exercise (Coding) | Image Preprocessing

# %% [markdown]
# The input size of DarkNet is `(416, 416)`, so we need to preprocess our image into the required size by resizing our image, keeping the aspect ratio consistent, and padding the left out areas with the grey color, which is `(128,128,128)` in RGB. We have implemented the preprocessing for you in the `preprocess_input(image, net_h, net_w)` function, which takes as input the original image, the target height (`net_h`) and target width (`net_w`) and returns the new image in the required size.
#
# In the chunk below, do the preprocessing by yourself! Plot the new image to check your result

# %%
### YOUR CODE HERE
net_h = 416
net_w = 416
new_image =preprocess_input(image_pil, net_h, net_w)

### END CODE

# %%
#@title Run this to check the new image { display-mode: "form" }
plt.imshow(new_image[0])
plt.show()

# %% [markdown]
# ### Exercise (Discussion) | DarkNet Architecture

# %% [markdown]
# The main part of the YOLO algorithm is the DarkNet model, which is basically a Convolutional Neural Network, with some special designs, like upsampling layers and detection layers.
#
# Here is what the architecture of DarkNet looks like:
#
#
# <img src="https://miro.medium.com/max/2000/1*d4Eg17IVJ0L41e7CTWLLSg.png" width="1000"/>
#
# **The residual blocks** in the picture contain layers that are similar to the CNN models we built before (e.g., convolutional layers `Conv2D`, max pooling layers `MaxPooling2D`, activation layers `Activation('relu')`). The network just stacks a lot more layers than the model we built before.
#
# **Upsampling** is the opposite of downsampling, a technique we have seen in CNN architecture in the form of Max Pooling. Below we see the familiar Max Pooling followed by various upsampling techniques, YOLOv3 uses the simplest of the 3, nearest neighbor, where values are just copied into the added cells according to which is nearest
#
#
# <img src="https://mriquestions.com/uploads/3/4/5/7/34572113/uppooling-methods_orig.png" width="600"/>

# %% [markdown]
# **How does YOLOv3 make detections at 3 different scales?**

# %% [markdown]
# Besides the stuff that we are familiar with, the most salient feature of YOLOv3 DarkNet is that it makes detections at three different scales, which are precisely given by downsampling the dimensions of the input image by 32, 16 and 8 respectively.
#
# The first detection is made by the 82nd layer. For the first 81 layers, the image is downsampled by the network, such that the 81st layer has a stride of 32. If we have an image of 416 x 416, the resultant feature map would be of size 13 x 13.
#
# The feature map size at layer 94 and 106 grows bigger because of the upsampling layers. The feature maps are upsampled by 2x to dimensions of 26 x 26 and 52 x 52 respectively.

# %% [markdown]
# **What exactly are the DarkNet outputs?**

# %% [markdown]
# The eventual detection output is generated by applying detection kernels on feature maps at the three different places in the network.
#
# For each grid cell, we'll consider several possible bounding boxes that are centered at the given grid cell. Then for each considered bounding box, the model predicts t<sub>x</sub>, t<sub>y</sub>, t<sub>w</sub>, t<sub>h</sub>, an objectness score, and class scores.
# - t<sub>x</sub>, t<sub>y</sub>, t<sub>w</sub>, t<sub>h</sub> are related to predicting the exact position and shape of the considered bounding box.
# - The objectness score is the model's prediction about how likely the considered bounding box has a complete object inside it.
# - Class scores are the predicted probability over all the object classes.
#
# Therefore, the shape of the detection kernel is 1 x 1 x (B x (4 + 1 + C)). Here, 1 x 1 means the kernel only looks at one grid cell at one time. B is the number of bounding boxes a cell on the feature map can predict, "4" is for the 4 bounding box attributes (t<sub>x</sub>, t<sub>y</sub>, t<sub>w</sub>, t<sub>h</sub>) and "1" for the object confidence. C is the number of object classes.
#
# The model will consider bounding boxes based on the 3 anchor boxes defined before, so B = 3. As YOLO is trained on COCO (a large-scale object detection dataset), which contains 80 object categories, C = 80. Therefore, the kernel size is 1 x 1 x 255. The feature map produced by this kernel has identical height and width of the previous feature map, and has detection attributes along the depth as described above.
#
# The following picture illustrates how this works.
#
# <img src="https://miro.medium.com/max/1200/0*3A8U0Hm5IKmRa6hu.png" width="500"/>

# %% [markdown]
# ### Exercise (Coding and Discussion) | Forward Pass

# %% [markdown]
# Now, let's load a fully trained DarkNet model!

# %%
import tensorflow as tf

# Load model
darknet = tf.keras.models.load_model(model_path, compile=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# Just as we got the classification predictions from the perceptron, CNN, and VGG models, call the `model.predict(input_data)` function to do a forward pass on our preprocessed image `new_image`!
#
# After you get the output, check the structure of the output and discuss what the dimensions mean with your classmates!

# %%
### YOUR CODE HERE
yolo_outputs = darknet.predict(new_image)
for element in yolo_outputs:
  print(element.shape)

### END CODE
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# (1, 13, 13, 255)
# (1, 26, 26, 255)
# (1, 52, 52, 255)

# %% [markdown]
# Answer the following questions:
#
#
# *   How many elements are there in `yolo_outputs`? Why?
# *   What does each dimension of `yolo_outputs[0]` mean?
# *   Why is the last dimension 255?
#
# If you are clear about the questions above, you can definitely explain how DarkNet works to your classmates! (At each detection scale, ... For each grid cell, ... For each bounding box, ...)

# %% [markdown]
# # Milestone 3. Bounding Box Prediction

# %% [markdown]
# We now have DarkNet's detection predictions for all the possible bounding boxes centered at each grid cell position, but to get the final detection results, which are the bounding boxes that the model is confident of, we need to apply a threshold to filter the results.
#
# Besides, as you can imagine, there might be multiple bounding boxes that are detecting the same object. We need to remove the overlapping bounding boxes and only leave the best ones.
#
# Here are some post-processing steps:

# %% [markdown]
# *   `decode_netout(yolo_outputs, obj_thresh, anchors, image_h, image_w, net_h, net_w)` takes the DarkNet output feature maps `yolo_outputs` as input, and returns all the predicted bounding boxes that have a higher objectness than the objectness threshold `obj_thresh`
# *   `do_nms(boxes, nms_thresh, obj_thresh)` means Non-Maximal Suppression, which is a commonly used post-processing step for object detection. It removes  all the bounding boxes that have a big (higher overlap than the `nms_thresh`) overlap with other better bounding boxes.
# *   `draw_boxes(image_pil, boxes, labels)` draws the final bounding boxes on the input image and return the detection image as a `PIL image`.

# %% [markdown]
# ### Exercise (Coding) | Post-processing for bounding box prediction

# %% [markdown]
# First, let's define the thresholds mentioned above:

# %%
obj_thresh = 0.4
nms_thresh = 0.45

# %% [markdown]
# Make use of the functions above to get our final detection bounding boxes and plot the result you get!

# %%
### YOUR CODE HERE
bounding_boxes= decode_netout(yolo_outputs, obj_thresh, anchors, image_h, image_w, net_h, net_w)
detected = draw_boxes(image_pil, bounding_boxes, labels)
### END CODE
# Out:
# person 0.51 (np.int32(325), np.int32(203)) (np.int32(348), np.int32(256))
# car 0.96 (np.int32(666), np.int32(191)) (720, np.int32(241))
# car 1.00 (np.int32(653), np.int32(189)) (720, np.int32(243))
# car 0.84 (np.int32(623), np.int32(190)) (np.int32(685), np.int32(239))
# person 0.88 (np.int32(325), np.int32(189)) (np.int32(348), np.int32(258))
# person 0.93 (np.int32(297), np.int32(185)) (np.int32(328), np.int32(253))
# car 0.90 (np.int32(650), np.int32(187)) (720, np.int32(237))
# car 0.99 (np.int32(625), np.int32(187)) (np.int32(688), np.int32(233))
# car 0.69 (np.int32(618), np.int32(189)) (np.int32(678), np.int32(233))
# traffic light 0.43 (np.int32(224), np.int32(123)) (np.int32(239), np.int32(153))
# car 0.60 (np.int32(632), np.int32(186)) (720, np.int32(238))
# car 0.46 (np.int32(614), np.int32(185)) (np.int32(697), np.int32(234))
# car 0.95 (np.int32(478), np.int32(180)) (np.int32(634), np.int32(255))
# car 0.98 (np.int32(462), np.int32(180)) (np.int32(635), np.int32(256))
# car 0.48 (np.int32(375), np.int32(181)) (np.int32(534), np.int32(243))
# person 0.46 (np.int32(296), np.int32(184)) (np.int32(342), np.int32(258))
# bus 0.91 (np.int32(353), np.int32(153)) (np.int32(555), np.int32(233))
# bus 0.47 (np.int32(339), np.int32(156)) (np.int32(537), np.int32(232))
# truck 0.85 (0, np.int32(173)) (np.int32(274), np.int32(285))
# bus 0.82 (np.int32(345), np.int32(144)) (np.int32(570), np.int32(237))
# bus 0.43 (np.int32(326), np.int32(146)) (np.int32(547), np.int32(239))
# truck 0.95 (0, np.int32(161)) (np.int32(268), np.int32(278))

# %% [markdown]
# ### Exercise (Coding) | Non-Maximal Suppression

# %% [markdown]
# Good job! Are you curious about what each post-processing step is doing? You can explore this by yourself!
#
# As a hint, you can...
#
# *   Check the number of boxes after each step
# *   Call the `draw_boxes(image_pil, boxes, labels)` function to visualize the bounding boxes after each step

# %%
### YOUR CODE HERE
bounding_boxes = do_nms(bounding_boxes, nms_thresh, obj_thresh)
draw_boxes(image_pil, bounding_boxes, labels)
### END CODE
# Out:
# car 1.00 (np.int32(653), np.int32(189)) (720, np.int32(243))
# person 0.88 (np.int32(325), np.int32(189)) (np.int32(348), np.int32(258))
# person 0.93 (np.int32(297), np.int32(185)) (np.int32(328), np.int32(253))
# car 0.99 (np.int32(625), np.int32(187)) (np.int32(688), np.int32(233))
# traffic light 0.43 (np.int32(224), np.int32(123)) (np.int32(239), np.int32(153))
# car 0.98 (np.int32(462), np.int32(180)) (np.int32(635), np.int32(256))
# car 0.48 (np.int32(375), np.int32(181)) (np.int32(534), np.int32(243))
# bus 0.91 (np.int32(353), np.int32(153)) (np.int32(555), np.int32(233))
# truck 0.95 (0, np.int32(161)) (np.int32(268), np.int32(278))
# <PIL.Image.Image image mode=RGB size=720x400>

# %% [markdown]
# ### Exercise (Coding) | Image Detection Function

# %% [markdown]
# Our final goal is to detect objects in a video, which contains multiple frames (images). For better reusability and modularity, let's wrap all the code we wrote before in a function called `detect_image`, which takes the raw `PIL image` (without preprocessing) and other parameters as input, and returns the `PIL image` with detected bounding boxes and labels. Complete this function by yourself and test it.

# %%
def detect_image(image_pil, obj_thresh = 0.4, nms_thresh = 0.45, darknet=darknet, net_h=416, net_w=416, anchors=anchors, labels=labels):
  ### YOUR CODE HERE
  #pre_processing
  image_w, image_h = image_pil.size
  new_image =preprocess_input(image_pil, net_h, net_w)
  #running predicitons
  yolo_outputs = darknet.predict(new_image)
  #decoding
  bounding_boxes= decode_netout(yolo_outputs, obj_thresh, anchors, image_h, image_w, net_h, net_w)
  #nms
  bounding_boxes = do_nms(bounding_boxes, nms_thresh, obj_thresh)
  #drawing the bounding boxes
  detected = draw_boxes(image_pil, bounding_boxes, labels)
  return detected
  ### END CODE

# %%
#@title Run this to check your function definition { display-mode: "form" }
plt.figure(figsize=(12,12))
plt.imshow(detect_image(image_pil))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# car 1.00 (np.int32(653), np.int32(189)) (720, np.int32(243))
# person 0.88 (np.int32(325), np.int32(189)) (np.int32(348), np.int32(258))
# person 0.93 (np.int32(297), np.int32(185)) (np.int32(328), np.int32(253))
# car 0.99 (np.int32(625), np.int32(187)) (np.int32(688), np.int32(233))
# traffic light 0.43 (np.int32(224), np.int32(123)) (np.int32(239), np.int32(153))
# car 0.98 (np.int32(462), np.int32(180)) (np.int32(635), np.int32(256))
# car 0.48 (np.int32(375), np.int32(181)) (np.int32(534), np.int32(243))
# bus 0.91 (np.int32(353), np.int32(153)) (np.int32(555), np.int32(233))
# truck 0.95 (0, np.int32(161)) (np.int32(268), np.int32(278))

# %% [markdown]
# ### Exercise (Discussion) | Thresholds

# %% [markdown]
# Up until now, we used default values for the 2 thresholds, `objectness threshold` and `nms_threshold`. Do you understand what these 2 thresholds control? Make use of the `detect_image`function we defined above, try different values for the 2 thresholds in the range of 0-1 and see the changes in the results. Then discuss this with your classmates!

# %% [markdown]
# # Milestone 4. Detection on Videos

# %% [markdown]
# A video is just a sequence of frames (images). Therefore, once we can use YOLO to detect objects on images, it's easy to extend this to videos. To deal with videos, we'll use the OpenCV package, which is called `cv2` in Python. If you are interested to know more, here is a [tutorial](https://docs.opencv.org/4.5.2/d0/de3/tutorial_py_intro.html).
#
# The code below will open one video, create a new video file, read the input video frame-by-frame, and write each frame into the new video.
#
# Now modify the code by yourself to get the object detection result on the input video!

# %% [markdown]
# Remember that the image input for the `detect_image` function is a `PIL image`, but here we are loading the input video using `OpenCV`. These 2 image formats are different, so we need to convert `OpenCV` to `PIL` for detection, and convert back to write the frame into the new video.
#
# The conversion can be done as follows
# ```python
# # OpenCV -> PIL
# image_pil = Image.fromarray(cv2.cvtColor(image_cv2, cv2.COLOR_BGR2RGB))
#
# # PIL -> OpenCV
# image_cv2 = cv2.cvtColor(np.asarray(image_pil), cv2.COLOR_RGB2BGR)
#
# ```

# %%
import cv2

def detect_video(video_path, output_path, obj_thresh = 0.4, nms_thresh = 0.45, darknet=darknet, net_h=416, net_w=416, anchors=anchors, labels=labels):
    vid = cv2.VideoCapture(video_path)
    if not vid.isOpened():
        raise IOError("Couldn't open webcam or video")
    video_FourCC    = int(vid.get(cv2.CAP_PROP_FOURCC))
    video_FourCC = cv2.VideoWriter_fourcc(*'mp4v')
    video_fps       = vid.get(cv2.CAP_PROP_FPS)
    video_size      = (int(vid.get(cv2.CAP_PROP_FRAME_WIDTH)),
                        int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT)))

    out = cv2.VideoWriter(output_path, video_FourCC, video_fps, video_size)

    num_frame = 0
    while vid.isOpened():
      ret, frame = vid.read()
      num_frame += 1
      print("=== Frame {} ===".format(num_frame))
      if ret:
          ### YOUR CODE HERE
          new_frame = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
          result = detect_image(new_frame)
          new_frame = cv2.cvtColor(np.asarray(result), cv2.COLOR_RGB2BGR)
          ### END CODE
          out.write(new_frame)
      else:
          break
    vid.release()
    out.release()
    print("New video saved!")

# %% [markdown]
# Now test your code! You can check the videos in the file explorer by clicking on the folder icon in the left sidebar.

# %%
video_path = '/content/data/video1.mp4'
output_path = '/content/data/video1_detected.mp4'
detect_video(video_path, output_path)
# Out:
# === Frame 1 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# car 0.98 (np.int32(400), np.int32(381)) (np.int32(490), np.int32(443))
# person 0.53 (np.int32(851), np.int32(368)) (np.int32(885), np.int32(418))
# car 0.72 (np.int32(368), np.int32(378)) (np.int32(413), np.int32(407))
# car 0.78 (np.int32(589), np.int32(358)) (np.int32(619), np.int32(385))
# car 0.94 (np.int32(2), np.int32(377)) (np.int32(124), np.int32(527))
# === Frame 2 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.99 (np.int32(401), np.int32(381)) (np.int32(490), np.int32(443))
# person 0.57 (np.int32(847), np.int32(361)) (np.int32(894), np.int32(425))
# car 0.52 (np.int32(747), np.int32(372)) (np.int32(802), np.int32(401))
# car 0.81 (np.int32(369), np.int32(378)) (np.int32(413), np.int32(407))
# car 0.72 (np.int32(589), np.int32(357)) (np.int32(620), np.int32(385))
# car 0.97 (np.int32(3), np.int32(374)) (np.int32(118), np.int32(530))
# car 0.51 (0, np.int32(581)) (np.int32(1262), 720)
# === Frame 3 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.98 (np.int32(403), np.int32(382)) (np.int32(487), np.int32(440))
# person 0.54 (np.int32(856), np.int32(367)) (np.int32(893), np.int32(418))
# car 0.68 (np.int32(747), np.int32(373)) (np.int32(807), np.int32(402))
# car 0.89 (np.int32(369), np.int32(379)) (np.int32(411), np.int32(406))
# car 0.70 (np.int32(590), np.int32(356)) (np.int32(621), np.int32(384))
# car 0.98 (np.int32(2), np.int32(372)) (np.int32(109), np.int32(531))
# === Frame 4 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.98 (np.int32(405), np.int32(384)) (np.int32(485), np.int32(439))
# car 0.60 (np.int32(749), np.int32(373)) (np.int32(810), np.int32(402))
# car 0.91 (np.int32(369), np.int32(379)) (np.int32(410), np.int32(406))
# car 0.67 (np.int32(589), np.int32(356)) (np.int32(624), np.int32(385))
# car 0.95 (np.int32(1), np.int32(369)) (np.int32(88), np.int32(532))
# === Frame 5 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.99 (np.int32(405), np.int32(384)) (np.int32(487), np.int32(439))
# person 0.42 (np.int32(853), np.int32(365)) (np.int32(905), np.int32(424))
# car 0.70 (np.int32(748), np.int32(372)) (np.int32(815), np.int32(405))
# car 0.92 (np.int32(369), np.int32(380)) (np.int32(409), np.int32(406))
# person 0.41 (np.int32(693), np.int32(361)) (np.int32(710), np.int32(401))
# car 0.41 (np.int32(609), np.int32(362)) (np.int32(635), np.int32(386))
# car 0.61 (np.int32(590), np.int32(356)) (np.int32(623), np.int32(384))
# car 0.96 (np.int32(2), np.int32(364)) (np.int32(80), np.int32(534))
# === Frame 6 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.98 (np.int32(410), np.int32(388)) (np.int32(485), np.int32(437))
# car 0.70 (np.int32(747), np.int32(374)) (np.int32(815), np.int32(404))
# car 0.92 (np.int32(369), np.int32(379)) (np.int32(410), np.int32(407))
# car 0.68 (np.int32(608), np.int32(362)) (np.int32(636), np.int32(388))
# car 0.65 (np.int32(590), np.int32(355)) (np.int32(626), np.int32(384))
# car 0.96 (np.int32(2), np.int32(370)) (np.int32(69), np.int32(531))
# === Frame 7 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.94 (0, np.int32(396)) (np.int32(58), np.int32(541))
# car 0.99 (np.int32(410), np.int32(385)) (np.int32(488), np.int32(438))
# person 0.55 (np.int32(869), np.int32(358)) (np.int32(912), np.int32(425))
# car 0.56 (np.int32(746), np.int32(373)) (np.int32(818), np.int32(405))
# car 0.92 (np.int32(369), np.int32(381)) (np.int32(409), np.int32(407))
# person 0.40 (np.int32(692), np.int32(363)) (np.int32(707), np.int32(397))
# car 0.58 (np.int32(608), np.int32(360)) (np.int32(637), np.int32(385))
# car 0.50 (np.int32(591), np.int32(354)) (np.int32(627), np.int32(383))
# === Frame 8 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.73 (0, np.int32(409)) (np.int32(41), np.int32(536))
# car 0.98 (np.int32(411), np.int32(386)) (np.int32(490), np.int32(438))
# person 0.49 (np.int32(867), np.int32(360)) (np.int32(914), np.int32(424))
# car 0.48 (np.int32(766), np.int32(373)) (np.int32(820), np.int32(403))
# car 0.40 (np.int32(422), np.int32(381)) (np.int32(485), np.int32(411))
# car 0.93 (np.int32(369), np.int32(380)) (np.int32(409), np.int32(407))
# car 0.72 (np.int32(609), np.int32(362)) (np.int32(638), np.int32(387))
# car 0.49 (np.int32(592), np.int32(354)) (np.int32(627), np.int32(382))
# === Frame 9 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.61 (np.int32(1), np.int32(408)) (np.int32(30), np.int32(535))
# car 0.98 (np.int32(410), np.int32(388)) (np.int32(492), np.int32(438))
# person 0.67 (np.int32(868), np.int32(360)) (np.int32(920), np.int32(427))
# car 0.53 (np.int32(761), np.int32(372)) (np.int32(824), np.int32(405))
# car 0.44 (np.int32(421), np.int32(381)) (np.int32(488), np.int32(411))
# car 0.93 (np.int32(366), np.int32(381)) (np.int32(409), np.int32(408))
# car 0.66 (np.int32(608), np.int32(360)) (np.int32(639), np.int32(387))
# === Frame 10 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.98 (np.int32(415), np.int32(385)) (np.int32(491), np.int32(439))
# person 0.76 (np.int32(869), np.int32(357)) (np.int32(920), np.int32(429))
# person 0.41 (np.int32(696), np.int32(367)) (np.int32(711), np.int32(407))
# car 0.92 (np.int32(368), np.int32(381)) (np.int32(409), np.int32(408))
# person 0.41 (np.int32(719), np.int32(357)) (np.int32(736), np.int32(403))
# car 0.78 (np.int32(612), np.int32(361)) (np.int32(640), np.int32(387))
# car 0.43 (np.int32(592), np.int32(353)) (np.int32(624), np.int32(380))
# traffic light 0.41 (np.int32(666), np.int32(314)) (np.int32(680), np.int32(334))
# === Frame 11 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# person 0.84 (np.int32(873), np.int32(359)) (np.int32(923), np.int32(430))
# car 0.55 (np.int32(767), np.int32(373)) (np.int32(827), np.int32(402))
# car 0.96 (np.int32(418), np.int32(379)) (np.int32(499), np.int32(428))
# car 0.97 (np.int32(365), np.int32(379)) (np.int32(408), np.int32(409))
# car 0.73 (np.int32(612), np.int32(361)) (np.int32(640), np.int32(386))
# traffic light 0.49 (np.int32(665), np.int32(312)) (np.int32(681), np.int32(334))
# car 0.52 (np.int32(32), np.int32(602)) (np.int32(1205), 720)
# === Frame 12 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# car 0.98 (np.int32(417), np.int32(385)) (np.int32(497), np.int32(440))
# car 0.47 (np.int32(853), np.int32(364)) (np.int32(941), np.int32(420))
# person 0.77 (np.int32(873), np.int32(358)) (np.int32(925), np.int32(430))
# car 0.82 (np.int32(765), np.int32(373)) (np.int32(835), np.int32(402))
# person 0.42 (np.int32(698), np.int32(367)) (np.int32(714), np.int32(407))
# car 0.40 (np.int32(426), np.int32(380)) (np.int32(493), np.int32(410))
# car 0.99 (np.int32(363), np.int32(380)) (np.int32(407), np.int32(410))
# car 0.83 (np.int32(611), np.int32(361)) (np.int32(641), np.int32(388))
# traffic light 0.40 (np.int32(666), np.int32(310)) (np.int32(682), np.int32(332))
# === Frame 13 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# car 0.96 (np.int32(418), np.int32(385)) (np.int32(495), np.int32(438))
# person 0.41 (np.int32(895), np.int32(358)) (np.int32(937), np.int32(431))
# car 0.51 (np.int32(858), np.int32(368)) (np.int32(944), np.int32(418))
# car 0.81 (np.int32(767), np.int32(373)) (np.int32(837), np.int32(402))
# car 0.57 (np.int32(424), np.int32(380)) (np.int32(495), np.int32(412))
# car 0.98 (np.int32(363), np.int32(381)) (np.int32(407), np.int32(411))
# car 0.75 (np.int32(608), np.int32(358)) (np.int32(640), np.int32(388))
# traffic light 0.46 (np.int32(667), np.int32(310)) (np.int32(683), np.int32(334))
# === Frame 14 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.97 (np.int32(419), np.int32(388)) (np.int32(497), np.int32(439))
# person 0.70 (np.int32(898), np.int32(356)) (np.int32(943), np.int32(433))
# car 0.70 (np.int32(767), np.int32(371)) (np.int32(844), np.int32(403))
# car 0.78 (np.int32(423), np.int32(381)) (np.int32(497), np.int32(412))
# car 0.97 (np.int32(363), np.int32(383)) (np.int32(405), np.int32(411))
# car 0.89 (np.int32(606), np.int32(358)) (np.int32(641), np.int32(388))
# traffic light 0.49 (np.int32(667), np.int32(310)) (np.int32(684), np.int32(335))
# === Frame 15 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# person 0.66 (np.int32(900), np.int32(356)) (np.int32(947), np.int32(436))
# car 0.75 (np.int32(768), np.int32(372)) (np.int32(844), np.int32(403))
# car 0.96 (np.int32(425), np.int32(379)) (np.int32(500), np.int32(428))
# car 0.98 (np.int32(364), np.int32(382)) (np.int32(406), np.int32(411))
# car 0.88 (np.int32(608), np.int32(358)) (np.int32(642), np.int32(388))
# === Frame 16 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.94 (np.int32(424), np.int32(388)) (np.int32(499), np.int32(437))
# person 0.76 (np.int32(903), np.int32(357)) (np.int32(950), np.int32(435))
# car 0.62 (np.int32(764), np.int32(373)) (np.int32(848), np.int32(405))
# car 0.52 (np.int32(428), np.int32(380)) (np.int32(496), np.int32(412))
# car 0.98 (np.int32(359), np.int32(383)) (np.int32(405), np.int32(412))
# car 0.43 (0, np.int32(372)) (np.int32(58), np.int32(420))
# car 0.86 (np.int32(609), np.int32(357)) (np.int32(643), np.int32(388))
# traffic light 0.43 (np.int32(667), np.int32(308)) (np.int32(682), np.int32(333))
# === Frame 17 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.96 (np.int32(426), np.int32(387)) (np.int32(502), np.int32(438))
# car 0.66 (np.int32(872), np.int32(365)) (np.int32(964), np.int32(425))
# person 0.53 (np.int32(899), np.int32(360)) (np.int32(954), np.int32(433))
# car 0.63 (np.int32(762), np.int32(371)) (np.int32(848), np.int32(406))
# car 0.98 (np.int32(358), np.int32(381)) (np.int32(405), np.int32(413))
# car 0.67 (np.int32(608), np.int32(356)) (np.int32(641), np.int32(387))
# traffic light 0.50 (np.int32(670), np.int32(311)) (np.int32(684), np.int32(332))
# === Frame 18 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# car 0.97 (np.int32(426), np.int32(389)) (np.int32(504), np.int32(440))
# person 0.45 (np.int32(923), np.int32(360)) (np.int32(964), np.int32(438))
# car 0.65 (np.int32(868), np.int32(368)) (np.int32(968), np.int32(420))
# car 0.67 (np.int32(782), np.int32(373)) (np.int32(853), np.int32(403))
# car 0.52 (np.int32(440), np.int32(384)) (np.int32(503), np.int32(415))
# car 0.99 (np.int32(358), np.int32(382)) (np.int32(403), np.int32(413))
# car 0.45 (0, np.int32(373)) (np.int32(56), np.int32(422))
# car 0.53 (np.int32(610), np.int32(356)) (np.int32(644), np.int32(388))
# === Frame 19 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.94 (np.int32(433), np.int32(388)) (np.int32(506), np.int32(438))
# person 0.83 (np.int32(923), np.int32(360)) (np.int32(964), np.int32(441))
# car 0.44 (np.int32(867), np.int32(368)) (np.int32(970), np.int32(421))
# car 0.74 (np.int32(782), np.int32(371)) (np.int32(852), np.int32(404))
# car 0.59 (np.int32(441), np.int32(383)) (np.int32(505), np.int32(413))
# car 0.98 (np.int32(359), np.int32(383)) (np.int32(403), np.int32(414))
# car 0.41 (0, np.int32(373)) (np.int32(58), np.int32(422))
# car 0.54 (np.int32(611), np.int32(356)) (np.int32(643), np.int32(386))
# === Frame 20 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.97 (np.int32(435), np.int32(387)) (np.int32(505), np.int32(439))
# person 0.94 (np.int32(926), np.int32(357)) (np.int32(971), np.int32(439))
# car 0.63 (np.int32(785), np.int32(374)) (np.int32(852), np.int32(403))
# car 0.51 (np.int32(443), np.int32(382)) (np.int32(502), np.int32(412))
# car 0.98 (np.int32(356), np.int32(383)) (np.int32(401), np.int32(416))
# car 0.47 (np.int32(612), np.int32(355)) (np.int32(645), np.int32(386))
# === Frame 21 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.98 (np.int32(436), np.int32(387)) (np.int32(506), np.int32(439))
# person 0.95 (np.int32(930), np.int32(361)) (np.int32(975), np.int32(439))
# car 0.65 (np.int32(792), np.int32(373)) (np.int32(853), np.int32(403))
# person 0.56 (np.int32(718), np.int32(372)) (np.int32(733), np.int32(407))
# car 0.48 (np.int32(446), np.int32(384)) (np.int32(503), np.int32(411))
# car 0.98 (np.int32(354), np.int32(384)) (np.int32(403), np.int32(416))
# car 0.48 (np.int32(613), np.int32(354)) (np.int32(646), np.int32(387))
# === Frame 22 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# car 0.98 (np.int32(438), np.int32(386)) (np.int32(508), np.int32(439))
# person 0.94 (np.int32(934), np.int32(361)) (np.int32(977), np.int32(440))
# car 0.50 (np.int32(869), np.int32(369)) (np.int32(976), np.int32(423))
# car 0.75 (np.int32(791), np.int32(373)) (np.int32(854), np.int32(404))
# car 0.97 (np.int32(353), np.int32(383)) (np.int32(401), np.int32(415))
# car 0.43 (np.int32(634), np.int32(365)) (np.int32(660), np.int32(390))
# === Frame 23 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.98 (np.int32(439), np.int32(385)) (np.int32(510), np.int32(440))
# person 0.93 (np.int32(934), np.int32(360)) (np.int32(979), np.int32(441))
# car 0.78 (np.int32(792), np.int32(373)) (np.int32(861), np.int32(406))
# person 0.55 (np.int32(720), np.int32(374)) (np.int32(735), np.int32(408))
# car 0.97 (np.int32(354), np.int32(383)) (np.int32(399), np.int32(415))
# car 0.50 (np.int32(635), np.int32(365)) (np.int32(660), np.int32(390))
# car 0.45 (np.int32(614), np.int32(355)) (np.int32(649), np.int32(386))
# === Frame 24 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.97 (np.int32(442), np.int32(385)) (np.int32(510), np.int32(440))
# person 0.88 (np.int32(946), np.int32(359)) (np.int32(982), np.int32(444))
# car 0.78 (np.int32(783), np.int32(373)) (np.int32(868), np.int32(407))
# car 0.48 (np.int32(449), np.int32(383)) (np.int32(507), np.int32(414))
# car 0.95 (np.int32(354), np.int32(385)) (np.int32(397), np.int32(413))
# car 0.41 (0, np.int32(382)) (np.int32(40), np.int32(420))
# car 0.48 (np.int32(634), np.int32(364)) (np.int32(661), np.int32(389))
# === Frame 25 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# car 0.97 (np.int32(442), np.int32(384)) (np.int32(512), np.int32(440))
# car 0.55 (np.int32(1091), np.int32(363)) (1280, np.int32(417))
# person 0.93 (np.int32(950), np.int32(355)) (np.int32(990), np.int32(440))
# car 0.86 (np.int32(783), np.int32(372)) (np.int32(872), np.int32(407))
# car 0.94 (np.int32(353), np.int32(385)) (np.int32(395), np.int32(416))
# car 0.56 (np.int32(636), np.int32(363)) (np.int32(662), np.int32(390))
# traffic light 0.40 (np.int32(691), np.int32(313)) (np.int32(708), np.int32(339))
# === Frame 26 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# car 0.96 (np.int32(444), np.int32(383)) (np.int32(516), np.int32(440))
# car 0.55 (np.int32(1097), np.int32(362)) (1280, np.int32(416))
# person 0.91 (np.int32(952), np.int32(355)) (np.int32(992), np.int32(440))
# car 0.68 (np.int32(785), np.int32(373)) (np.int32(869), np.int32(407))
# person 0.40 (np.int32(721), np.int32(375)) (np.int32(736), np.int32(408))
# car 0.93 (np.int32(336), np.int32(382)) (np.int32(394), np.int32(417))
# car 0.64 (np.int32(636), np.int32(363)) (np.int32(663), np.int32(390))
# === Frame 27 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# car 0.97 (np.int32(444), np.int32(384)) (np.int32(517), np.int32(441))
# person 0.95 (np.int32(957), np.int32(353)) (np.int32(998), np.int32(442))
# car 0.65 (np.int32(793), np.int32(372)) (np.int32(869), np.int32(406))
# person 0.45 (np.int32(724), np.int32(374)) (np.int32(738), np.int32(408))
# car 0.40 (np.int32(451), np.int32(381)) (np.int32(511), np.int32(413))
# car 0.98 (np.int32(331), np.int32(384)) (np.int32(395), np.int32(419))
# car 0.72 (np.int32(635), np.int32(362)) (np.int32(664), np.int32(389))
# === Frame 28 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.96 (np.int32(447), np.int32(386)) (np.int32(520), np.int32(439))
# person 0.77 (np.int32(962), np.int32(362)) (np.int32(1002), np.int32(441))
# car 0.59 (np.int32(897), np.int32(371)) (np.int32(990), np.int32(416))
# car 0.58 (np.int32(788), np.int32(372)) (np.int32(872), np.int32(407))
# car 0.97 (np.int32(335), np.int32(385)) (np.int32(394), np.int32(418))
# car 0.66 (np.int32(635), np.int32(362)) (np.int32(664), np.int32(390))
# === Frame 29 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.96 (np.int32(449), np.int32(385)) (np.int32(521), np.int32(439))
# person 0.67 (np.int32(970), np.int32(359)) (np.int32(1006), np.int32(449))
# car 0.58 (np.int32(894), np.int32(372)) (np.int32(992), np.int32(411))
# car 0.44 (np.int32(798), np.int32(372)) (np.int32(889), np.int32(405))
# car 0.42 (np.int32(451), np.int32(381)) (np.int32(517), np.int32(413))
# car 0.98 (np.int32(333), np.int32(385)) (np.int32(393), np.int32(418))
# car 0.72 (np.int32(634), np.int32(361)) (np.int32(665), np.int32(390))
# === Frame 30 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.97 (np.int32(450), np.int32(384)) (np.int32(522), np.int32(439))
# car 0.55 (np.int32(1102), np.int32(367)) (1280, np.int32(419))
# person 0.69 (np.int32(973), np.int32(354)) (np.int32(1014), np.int32(450))
# car 0.54 (np.int32(910), np.int32(374)) (np.int32(986), np.int32(406))
# car 0.72 (np.int32(800), np.int32(371)) (np.int32(886), np.int32(406))
# car 0.98 (np.int32(326), np.int32(385)) (np.int32(389), np.int32(420))
# car 0.72 (np.int32(634), np.int32(360)) (np.int32(665), np.int32(390))
# === Frame 31 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.98 (np.int32(451), np.int32(385)) (np.int32(525), np.int32(439))
# car 0.49 (np.int32(1106), np.int32(366)) (1280, np.int32(416))
# person 0.93 (np.int32(974), np.int32(354)) (np.int32(1018), np.int32(448))
# car 0.77 (np.int32(798), np.int32(371)) (np.int32(886), np.int32(407))
# car 0.98 (np.int32(327), np.int32(387)) (np.int32(384), np.int32(420))
# car 0.75 (np.int32(634), np.int32(360)) (np.int32(667), np.int32(391))
# === Frame 32 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.97 (np.int32(453), np.int32(384)) (np.int32(524), np.int32(439))
# car 0.51 (np.int32(1106), np.int32(365)) (1280, np.int32(416))
# person 0.93 (np.int32(978), np.int32(354)) (np.int32(1024), np.int32(450))
# car 0.45 (np.int32(909), np.int32(372)) (np.int32(993), np.int32(411))
# car 0.67 (np.int32(801), np.int32(372)) (np.int32(890), np.int32(407))
# person 0.49 (np.int32(739), np.int32(373)) (np.int32(757), np.int32(409))
# car 0.96 (np.int32(328), np.int32(388)) (np.int32(384), np.int32(418))
# car 0.63 (np.int32(634), np.int32(358)) (np.int32(668), np.int32(390))
# === Frame 33 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# car 0.97 (np.int32(454), np.int32(384)) (np.int32(525), np.int32(439))
# person 0.69 (np.int32(993), np.int32(360)) (np.int32(1033), np.int32(451))
# car 0.51 (np.int32(910), np.int32(372)) (np.int32(994), np.int32(408))
# car 0.84 (np.int32(803), np.int32(372)) (np.int32(892), np.int32(408))
# car 0.96 (np.int32(327), np.int32(388)) (np.int32(383), np.int32(421))
# car 0.64 (np.int32(632), np.int32(357)) (np.int32(668), np.int32(389))
# === Frame 34 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.94 (np.int32(454), np.int32(387)) (np.int32(526), np.int32(439))
# person 0.87 (np.int32(993), np.int32(359)) (np.int32(1036), np.int32(452))
# car 0.88 (np.int32(803), np.int32(373)) (np.int32(892), np.int32(410))
# person 0.54 (np.int32(739), np.int32(371)) (np.int32(757), np.int32(410))
# car 0.45 (np.int32(467), np.int32(384)) (np.int32(526), np.int32(415))
# car 0.92 (np.int32(324), np.int32(389)) (np.int32(383), np.int32(422))
# === Frame 35 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.90 (np.int32(461), np.int32(388)) (np.int32(526), np.int32(436))
# person 0.93 (np.int32(1003), np.int32(359)) (np.int32(1042), np.int32(452))
# car 0.87 (np.int32(804), np.int32(375)) (np.int32(893), np.int32(410))
# person 0.43 (np.int32(768), np.int32(365)) (np.int32(791), np.int32(413))
# person 0.67 (np.int32(740), np.int32(374)) (np.int32(757), np.int32(410))
# car 0.94 (np.int32(323), np.int32(387)) (np.int32(381), np.int32(421))
# car 0.50 (np.int32(633), np.int32(358)) (np.int32(668), np.int32(390))
# === Frame 36 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.94 (np.int32(462), np.int32(388)) (np.int32(526), np.int32(437))
# person 0.59 (np.int32(1006), np.int32(361)) (np.int32(1049), np.int32(446))
# car 0.85 (np.int32(803), np.int32(376)) (np.int32(895), np.int32(410))
# person 0.53 (np.int32(743), np.int32(375)) (np.int32(759), np.int32(410))
# car 0.85 (np.int32(321), np.int32(385)) (np.int32(382), np.int32(428))
# === Frame 37 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# person 0.83 (np.int32(1021), np.int32(369)) (np.int32(1057), np.int32(456))
# car 0.96 (np.int32(462), np.int32(387)) (np.int32(527), np.int32(437))
# car 0.85 (np.int32(308), np.int32(391)) (np.int32(384), np.int32(432))
# car 0.82 (np.int32(811), np.int32(377)) (np.int32(899), np.int32(410))
# person 0.53 (np.int32(744), np.int32(376)) (np.int32(759), np.int32(411))
# car 0.54 (np.int32(635), np.int32(358)) (np.int32(673), np.int32(391))
# traffic light 0.55 (np.int32(735), np.int32(313)) (np.int32(751), np.int32(343))
# === Frame 38 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# person 0.89 (np.int32(1023), np.int32(368)) (np.int32(1067), np.int32(458))
# car 0.97 (np.int32(463), np.int32(389)) (np.int32(528), np.int32(436))
# car 0.85 (np.int32(312), np.int32(391)) (np.int32(380), np.int32(432))
# car 0.89 (np.int32(812), np.int32(376)) (np.int32(900), np.int32(412))
# person 0.53 (np.int32(744), np.int32(377)) (np.int32(760), np.int32(411))
# truck 0.40 (np.int32(634), np.int32(355)) (np.int32(674), np.int32(389))
# truck 0.40 (np.int32(634), np.int32(355)) (np.int32(674), np.int32(389))
# traffic light 0.41 (np.int32(734), np.int32(316)) (np.int32(752), np.int32(345))
# === Frame 39 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# person 0.86 (np.int32(1031), np.int32(367)) (np.int32(1076), np.int32(458))
# car 0.96 (np.int32(463), np.int32(389)) (np.int32(529), np.int32(439))
# car 0.96 (np.int32(306), np.int32(390)) (np.int32(378), np.int32(436))
# car 0.81 (np.int32(812), np.int32(377)) (np.int32(899), np.int32(414))
# person 0.56 (np.int32(744), np.int32(377)) (np.int32(759), np.int32(412))
# truck 0.44 (np.int32(635), np.int32(356)) (np.int32(674), np.int32(391))
# truck 0.44 (np.int32(635), np.int32(356)) (np.int32(674), np.int32(391))
# traffic light 0.58 (np.int32(735), np.int32(316)) (np.int32(753), np.int32(346))
# === Frame 40 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# person 0.86 (np.int32(1044), np.int32(366)) (np.int32(1085), np.int32(458))
# car 0.98 (np.int32(466), np.int32(390)) (np.int32(531), np.int32(438))
# car 0.96 (np.int32(301), np.int32(392)) (np.int32(375), np.int32(436))
# car 0.80 (np.int32(821), np.int32(377)) (np.int32(912), np.int32(413))
# car 0.48 (np.int32(474), np.int32(387)) (np.int32(527), np.int32(417))
# truck 0.45 (np.int32(637), np.int32(356)) (np.int32(675), np.int32(391))
# traffic light 0.52 (np.int32(736), np.int32(317)) (np.int32(751), np.int32(345))
# === Frame 41 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# person 0.96 (np.int32(1049), np.int32(367)) (np.int32(1092), np.int32(460))
# car 0.98 (np.int32(467), np.int32(390)) (np.int32(533), np.int32(439))
# car 0.97 (np.int32(300), np.int32(391)) (np.int32(373), np.int32(438))
# car 0.59 (np.int32(1151), np.int32(368)) (1280, np.int32(417))
# car 0.80 (np.int32(821), np.int32(376)) (np.int32(913), np.int32(410))
# car 0.47 (np.int32(475), np.int32(388)) (np.int32(528), np.int32(417))
# car 0.47 (np.int32(657), np.int32(365)) (np.int32(686), np.int32(394))
# truck 0.50 (np.int32(636), np.int32(354)) (np.int32(676), np.int32(393))
# === Frame 42 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# person 0.86 (np.int32(1061), np.int32(367)) (np.int32(1097), np.int32(462))
# car 0.97 (np.int32(466), np.int32(389)) (np.int32(535), np.int32(443))
# car 0.97 (np.int32(292), np.int32(393)) (np.int32(373), np.int32(439))
# car 0.43 (np.int32(1160), np.int32(374)) (np.int32(1278), np.int32(417))
# car 0.43 (np.int32(960), np.int32(382)) (np.int32(1029), np.int32(406))
# car 0.75 (np.int32(823), np.int32(377)) (np.int32(915), np.int32(412))
# car 0.47 (np.int32(659), np.int32(376)) (np.int32(686), np.int32(397))
# car 0.52 (np.int32(477), np.int32(387)) (np.int32(528), np.int32(415))
# truck 0.42 (np.int32(637), np.int32(355)) (np.int32(678), np.int32(391))
# === Frame 43 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# person 0.92 (np.int32(1067), np.int32(364)) (np.int32(1108), np.int32(462))
# car 0.98 (np.int32(467), np.int32(389)) (np.int32(539), np.int32(443))
# car 0.98 (np.int32(289), np.int32(390)) (np.int32(371), np.int32(440))
# car 0.44 (np.int32(1162), np.int32(371)) (np.int32(1276), np.int32(416))
# car 0.45 (np.int32(962), np.int32(382)) (np.int32(1031), np.int32(407))
# car 0.76 (np.int32(821), np.int32(376)) (np.int32(914), np.int32(413))
# car 0.57 (np.int32(663), np.int32(376)) (np.int32(689), np.int32(398))
# truck 0.51 (np.int32(637), np.int32(353)) (np.int32(678), np.int32(392))
# traffic light 0.45 (np.int32(742), np.int32(316)) (np.int32(758), np.int32(342))
# === Frame 44 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# person 0.94 (np.int32(1077), np.int32(364)) (np.int32(1117), np.int32(467))
# car 0.99 (np.int32(466), np.int32(389)) (np.int32(543), np.int32(445))
# car 0.98 (np.int32(286), np.int32(390)) (np.int32(367), np.int32(441))
# car 0.59 (np.int32(955), np.int32(382)) (np.int32(1041), np.int32(409))
# car 0.80 (np.int32(820), np.int32(378)) (np.int32(918), np.int32(415))
# car 0.51 (np.int32(660), np.int32(376)) (np.int32(689), np.int32(398))
# truck 0.47 (np.int32(637), np.int32(355)) (np.int32(679), np.int32(390))
# traffic light 0.41 (np.int32(747), np.int32(316)) (np.int32(763), np.int32(343))
# traffic light 0.66 (np.int32(642), np.int32(295)) (np.int32(650), np.int32(314))
# === Frame 45 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# person 0.78 (np.int32(1081), np.int32(366)) (np.int32(1126), np.int32(466))
# car 0.99 (np.int32(468), np.int32(388)) (np.int32(544), np.int32(445))
# car 0.98 (np.int32(282), np.int32(392)) (np.int32(364), np.int32(441))
# car 0.68 (np.int32(949), np.int32(381)) (np.int32(1043), np.int32(411))
# car 0.85 (np.int32(824), np.int32(379)) (np.int32(920), np.int32(414))
# car 0.69 (np.int32(660), np.int32(376)) (np.int32(691), np.int32(399))
# traffic light 0.51 (np.int32(714), np.int32(306)) (np.int32(730), np.int32(330))
# === Frame 46 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# person 0.91 (np.int32(1093), np.int32(364)) (np.int32(1136), np.int32(468))
# car 0.99 (np.int32(468), np.int32(389)) (np.int32(546), np.int32(445))
# car 0.98 (np.int32(273), np.int32(391)) (np.int32(360), np.int32(445))
# car 0.73 (np.int32(947), np.int32(380)) (np.int32(1049), np.int32(411))
# car 0.85 (np.int32(828), np.int32(377)) (np.int32(920), np.int32(414))
# car 0.64 (np.int32(661), np.int32(377)) (np.int32(690), np.int32(398))
# car 0.42 (np.int32(657), np.int32(364)) (np.int32(688), np.int32(395))
# traffic light 0.41 (np.int32(752), np.int32(314)) (np.int32(767), np.int32(342))
# traffic light 0.45 (np.int32(715), np.int32(306)) (np.int32(731), np.int32(328))
# traffic light 0.48 (np.int32(644), np.int32(295)) (np.int32(653), np.int32(314))
# === Frame 47 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# person 0.96 (np.int32(1103), np.int32(370)) (np.int32(1145), np.int32(467))
# car 0.98 (np.int32(475), np.int32(387)) (np.int32(546), np.int32(443))
# car 0.98 (np.int32(266), np.int32(391)) (np.int32(362), np.int32(444))
# car 0.73 (np.int32(940), np.int32(380)) (np.int32(1058), np.int32(411))
# car 0.86 (np.int32(831), np.int32(375)) (np.int32(924), np.int32(413))
# === Frame 48 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# person 0.86 (np.int32(1116), np.int32(368)) (np.int32(1156), np.int32(469))
# car 0.97 (np.int32(476), np.int32(387)) (np.int32(549), np.int32(441))
# car 0.98 (np.int32(264), np.int32(390)) (np.int32(359), np.int32(445))
# car 0.46 (np.int32(1172), np.int32(371)) (np.int32(1277), np.int32(420))
# car 0.74 (np.int32(941), np.int32(379)) (np.int32(1058), np.int32(411))
# car 0.85 (np.int32(834), np.int32(374)) (np.int32(924), np.int32(414))
# person 0.63 (np.int32(766), np.int32(377)) (np.int32(782), np.int32(415))
# truck 0.41 (np.int32(658), np.int32(360)) (np.int32(691), np.int32(395))
# truck 0.41 (np.int32(658), np.int32(360)) (np.int32(691), np.int32(395))
# === Frame 49 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# person 0.56 (np.int32(1121), np.int32(364)) (np.int32(1164), np.int32(471))
# car 0.96 (np.int32(475), np.int32(389)) (np.int32(549), np.int32(441))
# car 0.98 (np.int32(256), np.int32(393)) (np.int32(353), np.int32(444))
# car 0.53 (np.int32(1167), np.int32(373)) (np.int32(1278), np.int32(421))
# car 0.86 (np.int32(936), np.int32(378)) (np.int32(1063), np.int32(411))
# car 0.88 (np.int32(832), np.int32(373)) (np.int32(929), np.int32(413))
# truck 0.47 (np.int32(656), np.int32(358)) (np.int32(692), np.int32(397))
# traffic light 0.66 (np.int32(757), np.int32(314)) (np.int32(776), np.int32(344))
# traffic light 0.58 (np.int32(646), np.int32(293)) (np.int32(656), np.int32(311))
# === Frame 50 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# car 0.95 (np.int32(487), np.int32(390)) (np.int32(550), np.int32(436))
# car 0.98 (np.int32(255), np.int32(392)) (np.int32(348), np.int32(444))
# car 0.52 (np.int32(1169), np.int32(377)) (np.int32(1279), np.int32(421))
# car 0.86 (np.int32(966), np.int32(378)) (np.int32(1071), np.int32(409))
# car 0.91 (np.int32(844), np.int32(375)) (np.int32(941), np.int32(410))
# traffic light 0.79 (np.int32(759), np.int32(310)) (np.int32(777), np.int32(345))
# === Frame 51 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# car 0.99 (np.int32(487), np.int32(389)) (np.int32(551), np.int32(436))
# car 0.97 (np.int32(250), np.int32(392)) (np.int32(347), np.int32(445))
# car 0.49 (np.int32(1169), np.int32(369)) (1280, np.int32(421))
# car 0.86 (np.int32(967), np.int32(378)) (np.int32(1072), np.int32(411))
# car 0.93 (np.int32(843), np.int32(374)) (np.int32(948), np.int32(412))
# person 0.48 (np.int32(767), np.int32(372)) (np.int32(785), np.int32(415))
# === Frame 52 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# car 0.99 (np.int32(488), np.int32(388)) (np.int32(551), np.int32(434))
# car 0.98 (np.int32(249), np.int32(389)) (np.int32(346), np.int32(443))
# car 0.56 (np.int32(1193), np.int32(370)) (np.int32(1275), np.int32(427))
# car 0.88 (np.int32(961), np.int32(375)) (np.int32(1079), np.int32(408))
# car 0.86 (np.int32(841), np.int32(372)) (np.int32(944), np.int32(411))
# truck 0.53 (np.int32(658), np.int32(355)) (np.int32(694), np.int32(394))
# traffic light 0.54 (np.int32(760), np.int32(306)) (np.int32(780), np.int32(340))
# === Frame 53 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# car 0.99 (np.int32(487), np.int32(388)) (np.int32(551), np.int32(434))
# car 0.99 (np.int32(231), np.int32(388)) (np.int32(340), np.int32(444))
# car 0.71 (np.int32(964), np.int32(373)) (np.int32(1080), np.int32(409))
# car 0.94 (np.int32(842), np.int32(371)) (np.int32(948), np.int32(411))
# person 0.46 (np.int32(787), np.int32(372)) (np.int32(803), np.int32(408))
# truck 0.40 (np.int32(659), np.int32(355)) (np.int32(698), np.int32(390))
# truck 0.40 (np.int32(659), np.int32(355)) (np.int32(698), np.int32(390))
# car 0.48 (np.int32(593), np.int32(356)) (np.int32(614), np.int32(372))
# traffic light 0.43 (np.int32(653), np.int32(290)) (np.int32(663), np.int32(310))
# === Frame 54 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# car 0.98 (np.int32(487), np.int32(387)) (np.int32(551), np.int32(434))
# car 0.98 (np.int32(222), np.int32(387)) (np.int32(336), np.int32(445))
# car 0.88 (np.int32(957), np.int32(373)) (np.int32(1088), np.int32(407))
# car 0.91 (np.int32(848), np.int32(371)) (np.int32(952), np.int32(411))
# person 0.52 (np.int32(813), np.int32(372)) (np.int32(827), np.int32(409))
# person 0.60 (np.int32(786), np.int32(371)) (np.int32(802), np.int32(411))
# truck 0.49 (np.int32(659), np.int32(349)) (np.int32(695), np.int32(389))
# traffic light 0.60 (np.int32(653), np.int32(289)) (np.int32(663), np.int32(308))
# === Frame 55 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.99 (np.int32(489), np.int32(387)) (np.int32(553), np.int32(434))
# car 0.97 (np.int32(219), np.int32(386)) (np.int32(334), np.int32(446))
# car 0.89 (np.int32(987), np.int32(371)) (np.int32(1093), np.int32(409))
# car 0.91 (np.int32(850), np.int32(372)) (np.int32(954), np.int32(411))
# person 0.43 (np.int32(813), np.int32(369)) (np.int32(828), np.int32(410))
# person 0.80 (np.int32(785), np.int32(369)) (np.int32(803), np.int32(416))
# truck 0.47 (np.int32(658), np.int32(350)) (np.int32(696), np.int32(388))
# === Frame 56 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.99 (np.int32(205), np.int32(380)) (np.int32(328), np.int32(447))
# car 0.89 (np.int32(955), np.int32(372)) (np.int32(1095), np.int32(408))
# car 0.83 (np.int32(854), np.int32(373)) (np.int32(954), np.int32(412))
# person 0.76 (np.int32(788), np.int32(369)) (np.int32(805), np.int32(414))
# car 0.99 (np.int32(493), np.int32(384)) (np.int32(553), np.int32(430))
# car 0.53 (np.int32(682), np.int32(361)) (np.int32(709), np.int32(390))
# truck 0.49 (np.int32(658), np.int32(349)) (np.int32(699), np.int32(387))
# traffic light 0.43 (np.int32(732), np.int32(294)) (np.int32(750), np.int32(316))
# traffic light 0.79 (np.int32(653), np.int32(284)) (np.int32(665), np.int32(307))
# === Frame 57 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.97 (np.int32(203), np.int32(380)) (np.int32(322), np.int32(447))
# car 0.87 (np.int32(985), np.int32(371)) (np.int32(1101), np.int32(407))
# car 0.85 (np.int32(856), np.int32(371)) (np.int32(954), np.int32(410))
# person 0.54 (np.int32(812), np.int32(369)) (np.int32(829), np.int32(408))
# person 0.89 (np.int32(788), np.int32(368)) (np.int32(809), np.int32(415))
# car 0.98 (np.int32(494), np.int32(384)) (np.int32(556), np.int32(430))
# car 0.78 (np.int32(679), np.int32(360)) (np.int32(710), np.int32(392))
# traffic light 0.46 (np.int32(784), np.int32(300)) (np.int32(802), np.int32(335))
# traffic light 0.55 (np.int32(776), np.int32(298)) (np.int32(794), np.int32(333))
# traffic light 0.45 (np.int32(654), np.int32(284)) (np.int32(666), np.int32(306))
# === Frame 58 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# person 0.95 (np.int32(1220), np.int32(359)) (np.int32(1267), np.int32(484))
# car 0.97 (np.int32(193), np.int32(385)) (np.int32(319), np.int32(447))
# car 0.84 (np.int32(988), np.int32(373)) (np.int32(1102), np.int32(407))
# car 0.88 (np.int32(864), np.int32(370)) (np.int32(969), np.int32(408))
# person 0.62 (np.int32(816), np.int32(370)) (np.int32(831), np.int32(408))
# person 0.86 (np.int32(790), np.int32(372)) (np.int32(809), np.int32(414))
# car 0.98 (np.int32(495), np.int32(383)) (np.int32(557), np.int32(430))
# car 0.78 (np.int32(681), np.int32(361)) (np.int32(711), np.int32(393))
# traffic light 0.62 (np.int32(776), np.int32(298)) (np.int32(794), np.int32(334))
# === Frame 59 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# person 0.82 (np.int32(1238), np.int32(356)) (np.int32(1278), np.int32(484))
# car 0.96 (np.int32(190), np.int32(386)) (np.int32(313), np.int32(447))
# car 0.76 (np.int32(981), np.int32(371)) (np.int32(1111), np.int32(406))
# car 0.87 (np.int32(866), np.int32(370)) (np.int32(970), np.int32(408))
# person 0.53 (np.int32(790), np.int32(365)) (np.int32(809), np.int32(414))
# car 0.98 (np.int32(497), np.int32(383)) (np.int32(558), np.int32(430))
# car 0.86 (np.int32(680), np.int32(360)) (np.int32(713), np.int32(392))
# bus 0.71 (np.int32(1135), np.int32(264)) (np.int32(1268), np.int32(396))
# === Frame 60 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# person 0.68 (np.int32(1248), np.int32(356)) (np.int32(1279), np.int32(484))
# car 0.96 (np.int32(179), np.int32(388)) (np.int32(299), np.int32(449))
# car 0.89 (np.int32(983), np.int32(370)) (np.int32(1114), np.int32(407))
# car 0.90 (np.int32(868), np.int32(369)) (np.int32(968), np.int32(410))
# person 0.41 (np.int32(820), np.int32(368)) (np.int32(835), np.int32(409))
# person 0.76 (np.int32(792), np.int32(365)) (np.int32(812), np.int32(414))
# car 0.99 (np.int32(497), np.int32(384)) (np.int32(558), np.int32(430))
# car 0.87 (np.int32(682), np.int32(360)) (np.int32(714), np.int32(392))
# traffic light 0.48 (np.int32(780), np.int32(297)) (np.int32(801), np.int32(336))
# bus 0.46 (np.int32(1139), np.int32(264)) (np.int32(1275), np.int32(399))
# === Frame 61 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.97 (np.int32(170), np.int32(389)) (np.int32(294), np.int32(450))
# car 0.93 (np.int32(1009), np.int32(369)) (np.int32(1122), np.int32(407))
# car 0.92 (np.int32(873), np.int32(368)) (np.int32(969), np.int32(411))
# person 0.46 (np.int32(796), np.int32(367)) (np.int32(816), np.int32(414))
# car 0.98 (np.int32(498), np.int32(383)) (np.int32(559), np.int32(429))
# car 0.82 (np.int32(682), np.int32(359)) (np.int32(715), np.int32(391))
# traffic light 0.43 (np.int32(904), np.int32(301)) (np.int32(925), np.int32(331))
# traffic light 0.63 (np.int32(782), np.int32(296)) (np.int32(805), np.int32(338))
# traffic light 0.61 (np.int32(663), np.int32(281)) (np.int32(672), np.int32(300))
# === Frame 62 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.98 (np.int32(159), np.int32(389)) (np.int32(292), np.int32(450))
# car 0.93 (np.int32(1011), np.int32(369)) (np.int32(1123), np.int32(406))
# car 0.93 (np.int32(875), np.int32(367)) (np.int32(969), np.int32(410))
# car 0.98 (np.int32(501), np.int32(384)) (np.int32(561), np.int32(429))
# car 0.89 (np.int32(683), np.int32(360)) (np.int32(717), np.int32(392))
# traffic light 0.63 (np.int32(783), np.int32(299)) (np.int32(806), np.int32(340))
# traffic light 0.47 (np.int32(663), np.int32(281)) (np.int32(672), np.int32(300))
# === Frame 63 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.99 (np.int32(136), np.int32(389)) (np.int32(282), np.int32(456))
# car 0.91 (np.int32(1006), np.int32(369)) (np.int32(1130), np.int32(406))
# car 0.88 (np.int32(877), np.int32(369)) (np.int32(974), np.int32(410))
# person 0.50 (np.int32(809), np.int32(369)) (np.int32(824), np.int32(410))
# car 0.98 (np.int32(500), np.int32(384)) (np.int32(561), np.int32(428))
# car 0.90 (np.int32(683), np.int32(359)) (np.int32(717), np.int32(391))
# traffic light 0.68 (np.int32(784), np.int32(299)) (np.int32(805), np.int32(335))
# traffic light 0.80 (np.int32(662), np.int32(281)) (np.int32(674), np.int32(299))
# === Frame 64 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.98 (np.int32(122), np.int32(390)) (np.int32(276), np.int32(457))
# car 0.84 (np.int32(1003), np.int32(369)) (np.int32(1136), np.int32(407))
# car 0.86 (np.int32(885), np.int32(369)) (np.int32(974), np.int32(411))
# person 0.57 (np.int32(808), np.int32(367)) (np.int32(825), np.int32(412))
# car 0.98 (np.int32(502), np.int32(384)) (np.int32(564), np.int32(428))
# car 0.88 (np.int32(683), np.int32(360)) (np.int32(719), np.int32(392))
# traffic light 0.68 (np.int32(787), np.int32(299)) (np.int32(806), np.int32(332))
# traffic light 0.40 (np.int32(746), np.int32(292)) (np.int32(762), np.int32(314))
# traffic light 0.64 (np.int32(664), np.int32(281)) (np.int32(674), np.int32(299))
# bus 0.42 (np.int32(1157), np.int32(248)) (1280, np.int32(399))
# === Frame 65 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# car 0.99 (np.int32(120), np.int32(386)) (np.int32(262), np.int32(458))
# car 0.86 (np.int32(1002), np.int32(370)) (np.int32(1138), np.int32(407))
# car 0.79 (np.int32(885), np.int32(370)) (np.int32(973), np.int32(408))
# person 0.45 (np.int32(840), np.int32(373)) (np.int32(855), np.int32(407))
# person 0.75 (np.int32(811), np.int32(369)) (np.int32(828), np.int32(413))
# car 0.98 (np.int32(504), np.int32(385)) (np.int32(565), np.int32(426))
# car 0.82 (np.int32(681), np.int32(357)) (np.int32(719), np.int32(391))
# traffic light 0.46 (np.int32(789), np.int32(298)) (np.int32(808), np.int32(332))
# traffic light 0.52 (np.int32(664), np.int32(272)) (np.int32(674), np.int32(293))
# bus 0.78 (np.int32(1159), np.int32(243)) (1280, np.int32(401))
# === Frame 66 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# car 0.99 (np.int32(102), np.int32(389)) (np.int32(256), np.int32(460))
# car 0.89 (np.int32(998), np.int32(369)) (np.int32(1143), np.int32(408))
# car 0.74 (np.int32(886), np.int32(368)) (np.int32(973), np.int32(407))
# person 0.66 (np.int32(842), np.int32(371)) (np.int32(858), np.int32(408))
# person 0.87 (np.int32(812), np.int32(367)) (np.int32(831), np.int32(416))
# car 0.98 (np.int32(505), np.int32(385)) (np.int32(566), np.int32(426))
# car 0.84 (np.int32(682), np.int32(356)) (np.int32(720), np.int32(390))
# traffic light 0.57 (np.int32(790), np.int32(297)) (np.int32(810), np.int32(334))
# bus 0.70 (np.int32(1162), np.int32(240)) (1280, np.int32(401))
# === Frame 67 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 1.00 (np.int32(77), np.int32(390)) (np.int32(250), np.int32(464))
# car 0.86 (np.int32(996), np.int32(369)) (np.int32(1145), np.int32(409))
# car 0.88 (np.int32(898), np.int32(368)) (np.int32(992), np.int32(408))
# person 0.60 (np.int32(846), np.int32(366)) (np.int32(863), np.int32(411))
# person 0.90 (np.int32(813), np.int32(366)) (np.int32(834), np.int32(416))
# car 0.98 (np.int32(506), np.int32(385)) (np.int32(567), np.int32(425))
# car 0.88 (np.int32(684), np.int32(358)) (np.int32(721), np.int32(390))
# traffic light 0.49 (np.int32(665), np.int32(271)) (np.int32(676), np.int32(293))
# bus 0.72 (np.int32(1162), np.int32(239)) (1280, np.int32(403))
# === Frame 68 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 1.00 (np.int32(68), np.int32(390)) (np.int32(238), np.int32(461))
# car 0.92 (np.int32(999), np.int32(369)) (np.int32(1148), np.int32(407))
# car 0.90 (np.int32(902), np.int32(365)) (np.int32(992), np.int32(408))
# person 0.50 (np.int32(849), np.int32(366)) (np.int32(864), np.int32(408))
# person 0.91 (np.int32(816), np.int32(364)) (np.int32(837), np.int32(415))
# car 0.97 (np.int32(505), np.int32(382)) (np.int32(569), np.int32(423))
# car 0.87 (np.int32(687), np.int32(357)) (np.int32(723), np.int32(388))
# traffic light 0.51 (np.int32(666), np.int32(270)) (np.int32(677), np.int32(293))
# === Frame 69 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# car 0.99 (np.int32(50), np.int32(388)) (np.int32(229), np.int32(464))
# car 0.90 (np.int32(1000), np.int32(370)) (np.int32(1150), np.int32(407))
# car 0.90 (np.int32(905), np.int32(366)) (np.int32(1000), np.int32(408))
# person 0.57 (np.int32(848), np.int32(365)) (np.int32(865), np.int32(409))
# person 0.86 (np.int32(816), np.int32(363)) (np.int32(837), np.int32(414))
# car 0.97 (np.int32(505), np.int32(378)) (np.int32(568), np.int32(421))
# car 0.83 (np.int32(685), np.int32(358)) (np.int32(723), np.int32(389))
# traffic light 0.49 (np.int32(794), np.int32(295)) (np.int32(814), np.int32(331))
# traffic light 0.46 (np.int32(667), np.int32(269)) (np.int32(678), np.int32(293))
# bus 0.72 (np.int32(1169), np.int32(245)) (1280, np.int32(397))
# === Frame 70 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.86 (np.int32(1004), np.int32(370)) (np.int32(1149), np.int32(406))
# car 0.85 (np.int32(910), np.int32(365)) (np.int32(996), np.int32(409))
# person 0.58 (np.int32(857), np.int32(368)) (np.int32(875), np.int32(410))
# person 0.43 (np.int32(848), np.int32(367)) (np.int32(862), np.int32(408))
# person 0.93 (np.int32(819), np.int32(362)) (np.int32(838), np.int32(416))
# car 0.98 (np.int32(507), np.int32(376)) (np.int32(569), np.int32(421))
# car 0.80 (np.int32(686), np.int32(360)) (np.int32(726), np.int32(389))
# traffic light 0.60 (np.int32(796), np.int32(289)) (np.int32(818), np.int32(324))
# traffic light 0.66 (np.int32(669), np.int32(268)) (np.int32(680), np.int32(292))
# car 0.99 (np.int32(22), np.int32(382)) (np.int32(226), np.int32(468))
# bus 0.56 (np.int32(1171), np.int32(239)) (1280, np.int32(397))
# === Frame 71 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# car 0.79 (np.int32(1016), np.int32(368)) (np.int32(1165), np.int32(407))
# car 0.76 (np.int32(918), np.int32(366)) (np.int32(1016), np.int32(406))
# person 0.62 (np.int32(860), np.int32(366)) (np.int32(878), np.int32(410))
# person 0.85 (np.int32(822), np.int32(361)) (np.int32(842), np.int32(416))
# car 0.98 (np.int32(508), np.int32(376)) (np.int32(569), np.int32(421))
# car 0.77 (np.int32(689), np.int32(356)) (np.int32(728), np.int32(387))
# traffic light 0.49 (np.int32(670), np.int32(267)) (np.int32(680), np.int32(291))
# car 1.00 (np.int32(5), np.int32(383)) (np.int32(216), np.int32(468))
# === Frame 72 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# car 0.84 (np.int32(1017), np.int32(369)) (np.int32(1168), np.int32(406))
# car 0.57 (np.int32(921), np.int32(365)) (np.int32(1015), np.int32(406))
# person 0.73 (np.int32(861), np.int32(368)) (np.int32(878), np.int32(409))
# person 0.46 (np.int32(832), np.int32(369)) (np.int32(847), np.int32(411))
# person 0.76 (np.int32(823), np.int32(364)) (np.int32(841), np.int32(415))
# car 0.94 (np.int32(508), np.int32(375)) (np.int32(569), np.int32(420))
# car 0.74 (np.int32(693), np.int32(356)) (np.int32(728), np.int32(387))
# truck 0.43 (np.int32(660), np.int32(336)) (np.int32(707), np.int32(374))
# traffic light 0.53 (np.int32(807), np.int32(285)) (np.int32(832), np.int32(324))
# car 0.99 (0, np.int32(383)) (np.int32(206), np.int32(469))
# === Frame 73 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.81 (np.int32(1018), np.int32(367)) (np.int32(1173), np.int32(408))
# car 0.75 (np.int32(924), np.int32(366)) (np.int32(1013), np.int32(406))
# person 0.65 (np.int32(862), np.int32(367)) (np.int32(881), np.int32(409))
# person 0.53 (np.int32(830), np.int32(363)) (np.int32(849), np.int32(414))
# car 0.94 (np.int32(508), np.int32(373)) (np.int32(569), np.int32(420))
# car 0.72 (np.int32(700), np.int32(358)) (np.int32(731), np.int32(384))
# traffic light 0.68 (np.int32(808), np.int32(284)) (np.int32(832), np.int32(325))
# traffic light 0.51 (np.int32(758), np.int32(285)) (np.int32(777), np.int32(310))
# car 0.99 (0, np.int32(382)) (np.int32(181), np.int32(474))
# === Frame 74 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# car 0.86 (np.int32(1022), np.int32(367)) (np.int32(1173), np.int32(407))
# person 0.58 (np.int32(831), np.int32(363)) (np.int32(851), np.int32(414))
# car 0.94 (np.int32(509), np.int32(372)) (np.int32(569), np.int32(420))
# car 0.79 (np.int32(926), np.int32(362)) (np.int32(1010), np.int32(402))
# person 0.59 (np.int32(863), np.int32(359)) (np.int32(882), np.int32(403))
# car 0.69 (np.int32(700), np.int32(358)) (np.int32(732), np.int32(384))
# traffic light 0.75 (np.int32(808), np.int32(283)) (np.int32(831), np.int32(323))
# traffic light 0.40 (np.int32(757), np.int32(284)) (np.int32(778), np.int32(306))
# traffic light 0.73 (np.int32(673), np.int32(265)) (np.int32(684), np.int32(290))
# car 0.99 (0, np.int32(382)) (np.int32(174), np.int32(477))
# === Frame 75 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# car 0.89 (np.int32(1026), np.int32(365)) (np.int32(1175), np.int32(408))
# car 0.70 (np.int32(928), np.int32(365)) (np.int32(1021), np.int32(407))
# person 0.54 (np.int32(866), np.int32(363)) (np.int32(884), np.int32(411))
# person 0.76 (np.int32(834), np.int32(363)) (np.int32(854), np.int32(414))
# car 0.92 (np.int32(512), np.int32(372)) (np.int32(577), np.int32(413))
# car 0.81 (np.int32(700), np.int32(357)) (np.int32(732), np.int32(386))
# traffic light 0.80 (np.int32(810), np.int32(280)) (np.int32(832), np.int32(322))
# traffic light 0.44 (np.int32(759), np.int32(284)) (np.int32(777), np.int32(307))
# traffic light 0.81 (np.int32(674), np.int32(266)) (np.int32(685), np.int32(290))
# car 0.99 (0, np.int32(379)) (np.int32(166), np.int32(479))
# === Frame 76 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# car 0.92 (np.int32(1038), np.int32(366)) (np.int32(1189), np.int32(409))
# person 0.51 (np.int32(869), np.int32(361)) (np.int32(889), np.int32(413))
# person 0.86 (np.int32(835), np.int32(360)) (np.int32(856), np.int32(416))
# car 0.96 (np.int32(512), np.int32(372)) (np.int32(577), np.int32(413))
# person 0.68 (np.int32(207), np.int32(376)) (np.int32(221), np.int32(407))
# car 0.63 (np.int32(930), np.int32(361)) (np.int32(1017), np.int32(402))
# car 0.81 (np.int32(701), np.int32(357)) (np.int32(733), np.int32(385))
# traffic light 0.49 (np.int32(837), np.int32(278)) (np.int32(853), np.int32(313))
# traffic light 0.61 (np.int32(811), np.int32(278)) (np.int32(832), np.int32(322))
# traffic light 0.87 (np.int32(673), np.int32(264)) (np.int32(686), np.int32(291))
# car 0.99 (0, np.int32(378)) (np.int32(143), np.int32(484))
# === Frame 77 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.99 (0, np.int32(382)) (np.int32(132), np.int32(478))
# car 0.83 (np.int32(1036), np.int32(367)) (np.int32(1195), np.int32(409))
# car 0.46 (np.int32(947), np.int32(366)) (np.int32(1037), np.int32(406))
# person 0.40 (np.int32(867), np.int32(363)) (np.int32(885), np.int32(410))
# person 0.78 (np.int32(836), np.int32(360)) (np.int32(857), np.int32(415))
# car 0.98 (np.int32(513), np.int32(372)) (np.int32(577), np.int32(413))
# person 0.71 (np.int32(207), np.int32(375)) (np.int32(221), np.int32(407))
# car 0.82 (np.int32(703), np.int32(356)) (np.int32(733), np.int32(385))
# traffic light 0.73 (np.int32(813), np.int32(279)) (np.int32(834), np.int32(324))
# traffic light 0.86 (np.int32(674), np.int32(262)) (np.int32(687), np.int32(289))
# === Frame 78 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# car 0.99 (0, np.int32(377)) (np.int32(113), np.int32(483))
# car 0.91 (np.int32(1043), np.int32(367)) (np.int32(1198), np.int32(410))
# car 0.54 (np.int32(949), np.int32(365)) (np.int32(1038), np.int32(408))
# ...
# car 0.57 (np.int32(489), np.int32(338)) (np.int32(514), np.int32(352))
# traffic light 0.77 (np.int32(881), np.int32(255)) (np.int32(895), np.int32(288))
# traffic light 0.99 (np.int32(662), np.int32(129)) (np.int32(690), np.int32(191))
# === Frame 282 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# car 0.67 (np.int32(1264), np.int32(372)) (1280, np.int32(425))
# car 1.00 (np.int32(34), np.int32(372)) (np.int32(178), np.int32(438))
# car 0.45 (np.int32(974), np.int32(348)) (np.int32(1014), np.int32(377))
# car 0.77 (np.int32(799), np.int32(347)) (np.int32(885), np.int32(382))
# car 0.82 (np.int32(689), np.int32(343)) (np.int32(753), np.int32(394))
# car 0.97 (np.int32(431), np.int32(346)) (np.int32(470), np.int32(379))
# car 0.40 (np.int32(636), np.int32(342)) (np.int32(663), np.int32(363))
# car 0.55 (np.int32(490), np.int32(338)) (np.int32(514), np.int32(352))
# traffic light 0.70 (np.int32(880), np.int32(255)) (np.int32(895), np.int32(287))
# traffic light 0.99 (np.int32(662), np.int32(129)) (np.int32(690), np.int32(191))
# === Frame 283 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.66 (np.int32(1263), np.int32(371)) (1280, np.int32(425))
# car 1.00 (np.int32(34), np.int32(372)) (np.int32(178), np.int32(437))
# car 0.43 (np.int32(974), np.int32(349)) (np.int32(1013), np.int32(376))
# car 0.78 (np.int32(798), np.int32(347)) (np.int32(884), np.int32(382))
# car 0.82 (np.int32(689), np.int32(344)) (np.int32(753), np.int32(394))
# car 0.95 (np.int32(430), np.int32(347)) (np.int32(469), np.int32(378))
# car 0.42 (np.int32(637), np.int32(342)) (np.int32(662), np.int32(362))
# car 0.46 (np.int32(491), np.int32(338)) (np.int32(515), np.int32(352))
# traffic light 0.67 (np.int32(880), np.int32(255)) (np.int32(895), np.int32(286))
# traffic light 0.99 (np.int32(662), np.int32(129)) (np.int32(690), np.int32(191))
# === Frame 284 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.71 (np.int32(1263), np.int32(370)) (np.int32(1279), np.int32(426))
# car 1.00 (np.int32(34), np.int32(371)) (np.int32(178), np.int32(437))
# car 0.41 (np.int32(974), np.int32(349)) (np.int32(1013), np.int32(377))
# car 0.79 (np.int32(798), np.int32(347)) (np.int32(885), np.int32(382))
# car 0.86 (np.int32(689), np.int32(344)) (np.int32(753), np.int32(394))
# car 0.96 (np.int32(427), np.int32(345)) (np.int32(469), np.int32(379))
# car 0.41 (np.int32(636), np.int32(342)) (np.int32(661), np.int32(363))
# car 0.42 (np.int32(565), np.int32(338)) (np.int32(584), np.int32(350))
# traffic light 0.63 (np.int32(880), np.int32(256)) (np.int32(895), np.int32(287))
# traffic light 0.99 (np.int32(661), np.int32(129)) (np.int32(690), np.int32(191))
# === Frame 285 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# car 0.61 (np.int32(1263), np.int32(369)) (np.int32(1279), np.int32(427))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(179), np.int32(437))
# car 0.47 (np.int32(974), np.int32(349)) (np.int32(1014), np.int32(376))
# car 0.78 (np.int32(798), np.int32(347)) (np.int32(885), np.int32(381))
# car 0.87 (np.int32(688), np.int32(344)) (np.int32(752), np.int32(393))
# car 0.96 (np.int32(425), np.int32(345)) (np.int32(469), np.int32(379))
# car 0.40 (np.int32(636), np.int32(342)) (np.int32(661), np.int32(363))
# car 0.47 (np.int32(564), np.int32(337)) (np.int32(584), np.int32(349))
# traffic light 0.67 (np.int32(873), np.int32(258)) (np.int32(894), np.int32(293))
# traffic light 0.99 (np.int32(661), np.int32(129)) (np.int32(690), np.int32(191))
# === Frame 286 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# car 0.57 (np.int32(1262), np.int32(370)) (np.int32(1279), np.int32(429))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(179), np.int32(437))
# car 0.45 (np.int32(973), np.int32(348)) (np.int32(1014), np.int32(377))
# car 0.75 (np.int32(798), np.int32(347)) (np.int32(885), np.int32(381))
# car 0.87 (np.int32(688), np.int32(344)) (np.int32(752), np.int32(393))
# car 0.95 (np.int32(424), np.int32(346)) (np.int32(469), np.int32(379))
# car 0.49 (np.int32(566), np.int32(337)) (np.int32(584), np.int32(349))
# traffic light 0.73 (np.int32(873), np.int32(257)) (np.int32(894), np.int32(293))
# traffic light 0.99 (np.int32(660), np.int32(130)) (np.int32(690), np.int32(190))
# === Frame 287 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# car 0.57 (np.int32(1262), np.int32(370)) (np.int32(1279), np.int32(429))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(179), np.int32(437))
# car 0.45 (np.int32(974), np.int32(348)) (np.int32(1014), np.int32(377))
# car 0.75 (np.int32(798), np.int32(347)) (np.int32(885), np.int32(381))
# car 0.87 (np.int32(688), np.int32(344)) (np.int32(752), np.int32(393))
# car 0.95 (np.int32(424), np.int32(346)) (np.int32(469), np.int32(379))
# car 0.49 (np.int32(566), np.int32(337)) (np.int32(585), np.int32(349))
# traffic light 0.74 (np.int32(873), np.int32(257)) (np.int32(894), np.int32(293))
# traffic light 0.99 (np.int32(660), np.int32(130)) (np.int32(690), np.int32(190))
# === Frame 288 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# car 0.58 (np.int32(1262), np.int32(370)) (np.int32(1279), np.int32(429))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(178), np.int32(437))
# car 0.47 (np.int32(973), np.int32(348)) (np.int32(1014), np.int32(377))
# car 0.75 (np.int32(798), np.int32(347)) (np.int32(885), np.int32(381))
# car 0.86 (np.int32(689), np.int32(344)) (np.int32(752), np.int32(393))
# car 0.95 (np.int32(424), np.int32(346)) (np.int32(469), np.int32(379))
# car 0.51 (np.int32(566), np.int32(337)) (np.int32(585), np.int32(349))
# traffic light 0.75 (np.int32(872), np.int32(257)) (np.int32(894), np.int32(293))
# traffic light 0.99 (np.int32(661), np.int32(130)) (np.int32(690), np.int32(190))
# === Frame 289 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# car 0.56 (np.int32(1260), np.int32(369)) (np.int32(1279), np.int32(430))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(179), np.int32(437))
# car 0.42 (np.int32(974), np.int32(348)) (np.int32(1012), np.int32(377))
# car 0.67 (np.int32(797), np.int32(347)) (np.int32(886), np.int32(380))
# car 0.85 (np.int32(689), np.int32(344)) (np.int32(752), np.int32(393))
# car 0.93 (np.int32(423), np.int32(346)) (np.int32(467), np.int32(379))
# car 0.49 (np.int32(634), np.int32(341)) (np.int32(663), np.int32(365))
# car 0.51 (np.int32(564), np.int32(337)) (np.int32(583), np.int32(349))
# car 0.54 (np.int32(493), np.int32(338)) (np.int32(514), np.int32(350))
# car 0.49 (np.int32(472), np.int32(339)) (np.int32(496), np.int32(355))
# car 0.48 (np.int32(433), np.int32(343)) (np.int32(464), np.int32(365))
# traffic light 0.81 (np.int32(872), np.int32(256)) (np.int32(893), np.int32(291))
# traffic light 0.99 (np.int32(659), np.int32(131)) (np.int32(688), np.int32(190))
# === Frame 290 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# car 0.55 (np.int32(1259), np.int32(371)) (np.int32(1279), np.int32(430))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(179), np.int32(437))
# car 0.60 (np.int32(797), np.int32(347)) (np.int32(886), np.int32(380))
# car 0.87 (np.int32(688), np.int32(343)) (np.int32(752), np.int32(393))
# car 0.91 (np.int32(422), np.int32(347)) (np.int32(467), np.int32(379))
# car 0.46 (np.int32(635), np.int32(342)) (np.int32(662), np.int32(364))
# car 0.44 (np.int32(564), np.int32(337)) (np.int32(583), np.int32(348))
# car 0.48 (np.int32(493), np.int32(337)) (np.int32(514), np.int32(350))
# car 0.61 (np.int32(471), np.int32(339)) (np.int32(497), np.int32(354))
# traffic light 0.82 (np.int32(871), np.int32(257)) (np.int32(893), np.int32(292))
# traffic light 0.99 (np.int32(659), np.int32(132)) (np.int32(688), np.int32(189))
# === Frame 291 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# car 0.43 (np.int32(1258), np.int32(370)) (np.int32(1279), np.int32(430))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(180), np.int32(437))
# car 0.61 (np.int32(797), np.int32(347)) (np.int32(885), np.int32(380))
# car 0.87 (np.int32(688), np.int32(342)) (np.int32(752), np.int32(393))
# car 0.89 (np.int32(422), np.int32(347)) (np.int32(467), np.int32(380))
# car 0.47 (np.int32(635), np.int32(341)) (np.int32(663), np.int32(365))
# car 0.40 (np.int32(564), np.int32(336)) (np.int32(583), np.int32(348))
# car 0.49 (np.int32(492), np.int32(336)) (np.int32(514), np.int32(350))
# car 0.67 (np.int32(469), np.int32(336)) (np.int32(498), np.int32(354))
# traffic light 0.81 (np.int32(871), np.int32(257)) (np.int32(892), np.int32(292))
# traffic light 0.99 (np.int32(659), np.int32(132)) (np.int32(688), np.int32(190))
# === Frame 292 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# car 0.53 (np.int32(1256), np.int32(370)) (np.int32(1279), np.int32(431))
# car 1.00 (np.int32(34), np.int32(371)) (np.int32(180), np.int32(436))
# car 0.66 (np.int32(798), np.int32(346)) (np.int32(884), np.int32(380))
# car 0.88 (np.int32(688), np.int32(343)) (np.int32(752), np.int32(392))
# car 0.89 (np.int32(422), np.int32(347)) (np.int32(467), np.int32(380))
# car 0.47 (np.int32(634), np.int32(342)) (np.int32(663), np.int32(364))
# car 0.47 (np.int32(494), np.int32(337)) (np.int32(514), np.int32(350))
# car 0.72 (np.int32(469), np.int32(336)) (np.int32(497), np.int32(353))
# traffic light 0.83 (np.int32(870), np.int32(258)) (np.int32(892), np.int32(292))
# traffic light 0.99 (np.int32(659), np.int32(132)) (np.int32(688), np.int32(189))
# === Frame 293 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# car 0.62 (np.int32(1249), np.int32(358)) (1280, np.int32(439))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(181), np.int32(436))
# car 0.67 (np.int32(797), np.int32(347)) (np.int32(884), np.int32(380))
# car 0.86 (np.int32(688), np.int32(343)) (np.int32(752), np.int32(392))
# car 0.85 (np.int32(418), np.int32(347)) (np.int32(463), np.int32(379))
# car 0.45 (np.int32(634), np.int32(343)) (np.int32(662), np.int32(364))
# car 0.41 (np.int32(563), np.int32(337)) (np.int32(583), np.int32(348))
# car 0.48 (np.int32(494), np.int32(337)) (np.int32(514), np.int32(350))
# car 0.75 (np.int32(470), np.int32(337)) (np.int32(496), np.int32(353))
# traffic light 0.87 (np.int32(870), np.int32(257)) (np.int32(891), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(132)) (np.int32(688), np.int32(189))
# === Frame 294 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# car 0.61 (np.int32(1249), np.int32(357)) (1280, np.int32(440))
# car 1.00 (np.int32(35), np.int32(371)) (np.int32(181), np.int32(436))
# car 0.67 (np.int32(797), np.int32(347)) (np.int32(884), np.int32(380))
# car 0.86 (np.int32(688), np.int32(343)) (np.int32(752), np.int32(392))
# car 0.93 (np.int32(415), np.int32(343)) (np.int32(466), np.int32(381))
# car 0.44 (np.int32(634), np.int32(343)) (np.int32(662), np.int32(364))
# car 0.42 (np.int32(563), np.int32(337)) (np.int32(583), np.int32(349))
# car 0.47 (np.int32(494), np.int32(338)) (np.int32(514), np.int32(350))
# car 0.73 (np.int32(469), np.int32(336)) (np.int32(496), np.int32(353))
# traffic light 0.89 (np.int32(870), np.int32(256)) (np.int32(891), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(688), np.int32(189))
# === Frame 295 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# car 0.64 (np.int32(1248), np.int32(358)) (1280, np.int32(440))
# car 0.99 (np.int32(36), np.int32(371)) (np.int32(181), np.int32(436))
# car 0.69 (np.int32(790), np.int32(346)) (np.int32(875), np.int32(380))
# car 0.86 (np.int32(687), np.int32(343)) (np.int32(752), np.int32(392))
# car 0.95 (np.int32(412), np.int32(343)) (np.int32(468), np.int32(382))
# car 0.45 (np.int32(634), np.int32(343)) (np.int32(662), np.int32(363))
# car 0.44 (np.int32(563), np.int32(337)) (np.int32(583), np.int32(349))
# car 0.45 (np.int32(494), np.int32(338)) (np.int32(514), np.int32(350))
# car 0.72 (np.int32(469), np.int32(336)) (np.int32(495), np.int32(353))
# traffic light 0.88 (np.int32(870), np.int32(254)) (np.int32(891), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(688), np.int32(189))
# === Frame 296 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# car 0.77 (np.int32(1246), np.int32(360)) (1280, np.int32(439))
# car 0.99 (np.int32(37), np.int32(370)) (np.int32(180), np.int32(436))
# car 0.74 (np.int32(790), np.int32(346)) (np.int32(875), np.int32(380))
# car 0.87 (np.int32(687), np.int32(343)) (np.int32(751), np.int32(392))
# car 0.96 (np.int32(410), np.int32(346)) (np.int32(468), np.int32(382))
# car 0.44 (np.int32(635), np.int32(343)) (np.int32(661), np.int32(363))
# car 0.43 (np.int32(563), np.int32(337)) (np.int32(583), np.int32(349))
# car 0.42 (np.int32(493), np.int32(337)) (np.int32(514), np.int32(350))
# car 0.73 (np.int32(468), np.int32(336)) (np.int32(496), np.int32(353))
# traffic light 0.86 (np.int32(870), np.int32(255)) (np.int32(891), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(688), np.int32(189))
# === Frame 297 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# car 0.83 (np.int32(1243), np.int32(360)) (1280, np.int32(440))
# car 0.99 (np.int32(37), np.int32(370)) (np.int32(181), np.int32(436))
# car 0.77 (np.int32(790), np.int32(346)) (np.int32(875), np.int32(380))
# car 0.87 (np.int32(687), np.int32(344)) (np.int32(751), np.int32(392))
# car 0.95 (np.int32(409), np.int32(347)) (np.int32(466), np.int32(382))
# car 0.43 (np.int32(635), np.int32(343)) (np.int32(662), np.int32(364))
# car 0.44 (np.int32(563), np.int32(336)) (np.int32(583), np.int32(349))
# car 0.44 (np.int32(493), np.int32(337)) (np.int32(514), np.int32(350))
# car 0.71 (np.int32(468), np.int32(336)) (np.int32(496), np.int32(353))
# car 0.40 (np.int32(414), np.int32(343)) (np.int32(451), np.int32(368))
# traffic light 0.85 (np.int32(870), np.int32(256)) (np.int32(891), np.int32(292))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(688), np.int32(189))
# === Frame 298 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# car 0.85 (np.int32(1243), np.int32(360)) (np.int32(1279), np.int32(439))
# car 1.00 (np.int32(37), np.int32(370)) (np.int32(182), np.int32(436))
# car 0.75 (np.int32(789), np.int32(346)) (np.int32(876), np.int32(380))
# car 0.89 (np.int32(687), np.int32(343)) (np.int32(751), np.int32(392))
# car 0.96 (np.int32(407), np.int32(345)) (np.int32(465), np.int32(382))
# car 0.42 (np.int32(635), np.int32(343)) (np.int32(662), np.int32(363))
# car 0.45 (np.int32(563), np.int32(336)) (np.int32(583), np.int32(349))
# car 0.49 (np.int32(493), np.int32(337)) (np.int32(514), np.int32(351))
# car 0.69 (np.int32(468), np.int32(335)) (np.int32(496), np.int32(353))
# traffic light 0.86 (np.int32(870), np.int32(256)) (np.int32(891), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(688), np.int32(189))
# === Frame 299 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# car 0.85 (np.int32(1241), np.int32(361)) (np.int32(1279), np.int32(438))
# car 1.00 (np.int32(37), np.int32(371)) (np.int32(182), np.int32(435))
# car 0.75 (np.int32(789), np.int32(346)) (np.int32(876), np.int32(380))
# car 0.90 (np.int32(686), np.int32(343)) (np.int32(751), np.int32(393))
# car 0.96 (np.int32(407), np.int32(346)) (np.int32(463), np.int32(383))
# car 0.41 (np.int32(635), np.int32(343)) (np.int32(662), np.int32(363))
# car 0.46 (np.int32(562), np.int32(337)) (np.int32(583), np.int32(349))
# car 0.53 (np.int32(494), np.int32(337)) (np.int32(515), np.int32(351))
# car 0.70 (np.int32(467), np.int32(335)) (np.int32(496), np.int32(353))
# traffic light 0.86 (np.int32(870), np.int32(256)) (np.int32(890), np.int32(293))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(687), np.int32(190))
# === Frame 300 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# car 0.87 (np.int32(1238), np.int32(363)) (np.int32(1278), np.int32(436))
# car 1.00 (np.int32(38), np.int32(371)) (np.int32(182), np.int32(435))
# car 0.73 (np.int32(790), np.int32(346)) (np.int32(875), np.int32(380))
# car 0.92 (np.int32(686), np.int32(343)) (np.int32(751), np.int32(393))
# car 0.95 (np.int32(406), np.int32(345)) (np.int32(461), np.int32(382))
# car 0.46 (np.int32(635), np.int32(343)) (np.int32(662), np.int32(363))
# car 0.49 (np.int32(563), np.int32(337)) (np.int32(582), np.int32(349))
# car 0.55 (np.int32(494), np.int32(337)) (np.int32(515), np.int32(351))
# car 0.72 (np.int32(466), np.int32(335)) (np.int32(495), np.int32(354))
# traffic light 0.86 (np.int32(869), np.int32(256)) (np.int32(889), np.int32(295))
# traffic light 0.99 (np.int32(659), np.int32(133)) (np.int32(687), np.int32(190))
# === Frame 301 ===
# New video saved!

# %% [markdown]
# # Notebook Summary
#
# In today's notebook, we've explored the Yolo algorithm, which consists of a deep CNN called DarkNet and further postprocessing to output bounding boxes around the detected objects in the image. We then furthered the scope of our problem to include video data and detect objects frame-by-frame.
#
# Now that we have explored a variety of image classification methods, it's time to get ready for presentation day!
